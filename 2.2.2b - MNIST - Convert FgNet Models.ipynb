# %%
# Here I load the pre-trained Classical Nets after converting them to Finite Gaussian Nets
# 1 - load classical network
# 2 - convert to fgn
# 3 - check mnist performance
# 4 - lower sigma until performance hit (no retraining)
# 6 - save results

# %%
from __future__ import print_function

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

import numpy as np
from scipy import stats

import torch_helper_lib as th

import json
import pickle

# %%
# random seeds
# torch.manual_seed(1665)
# np.random.seed(3266)

# torch.backends.cudnn.deterministic = True
# torch.cuda.manual_seed_all(999)

# %%
# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
use_cuda = False
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")
print("Using device:", device)
# Out:
# CUDA Available:  True
# Using device: cpu

# %%
import matplotlib as mpl
# set this 'backend' when using jupyter; do this before importing pyplot
mpl.use('nbagg')
import matplotlib.pyplot as plt

# %%
# MNIST dataset and dataloader declaration
# transforms does both the conversion from 0-255 to 0-1
# and normalizes by the precomputed mean and std

batch_size = 64

mnist_train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../MNIST-dataset', train=True, download=False, 
                   transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))
            ])), 
        batch_size=batch_size, shuffle=True)

mnist_test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../MNIST-dataset', train=False, download=False, 
                   transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))
            ])), 
        batch_size=batch_size, shuffle=False)

# %%
# show an example
print("Shape:", mnist_train_loader.dataset.train_data.shape)
x = mnist_train_loader.dataset.train_data[1]
print("type:", type(x.numpy()))
print("shape:", x.shape)
# print("sample:", x.numpy())

y = mnist_train_loader.dataset.train_labels[1]
print("Label:",y.numpy())
print("type:", type(y))

plt.imshow(x, cmap=plt.cm.get_cmap('Greys'))
plt.colorbar()
plt.show()
# Out:
# Shape: torch.Size([60000, 28, 28])
# type: <type 'numpy.ndarray'>
# shape: torch.Size([28, 28])
# Label: 0
# type: <class 'torch.Tensor'>
# <div id='5ecad501-2e9d-4c35-9ba1-3285f99d2e2f'></div>

# %%
# list of sizes to try
network_sizes = [[], [8], [128], [1024], [8,8], [128,128], [1024,1024], [8,8,8], [128,128,128], [1024,1024,1024]]

# %%
# pre-trained classic models 
model_dir = "./saved_models/Classic_MNIST_Nets"
model_id = "./saved_models/Classic_MNIST_Nets/model_[8]"
exp_num = "_exp_0"
full_model = "_full.pth"
state_dict = "_state_dict.pth"

full_path = model_id+exp_num+full_model
dict_path = model_id+exp_num+state_dict
print(dict_path)
# Out:
# ./saved_models/Classic_MNIST_Nets/model_[8]_exp_0_state_dict.pth

# %%
save_path= "./saved_models/Retrained_FG_Nets//"

# %%
# functions for test
# nll loss function
def classic_nll_loss_func(model, output, target):
    return F.nll_loss(output, target)
# number of correct pred function for classic net
def classic_pred_func(output, target):
    output = output
    pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
    correct = pred.eq(target.long().view_as(pred)).sum().item()
    return correct

# nll loss function
def fgn_nll_loss_func(model, output, target):
    # split output into pred and likelihoods
    output, likelihood = output
    return F.nll_loss(output, target)    
# number of correct pred function for fgnet
def fgn_pred_func(output, target):
    output,_ = output
    pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
    correct = pred.eq(target.long().view_as(pred)).sum().item()
    return correct

# %%
# helper functions for manipulating the sigma of fgnets

def half_sigma(model):
    # given a model, divides the sigma of each FGN layer by 2
    for p in model.modules():
        if isinstance(p, th.FGN_layer):
            p.sigs = torch.nn.Parameter(p.sigs/2.0)
            
def double_sigma(model):
    # given a model, doubles the sigma of each FGN layer by 2
    for p in model.modules():
        if isinstance(p, th.FGN_layer):
            p.sigs = torch.nn.Parameter(p.sigs*2.0)

# %%
# for each classical network
for s in network_sizes:
    print("Working on size:", s)
    # for each exp 
    for exp_num in range(12):
        print("Working on exp:", exp_num)
        
        # create classic model
        classic_model = th.Classic_MNIST_Net(hidden_l_nums=s)
        #state dict
        # dict load
        classic_model_path = model_dir+'/model_'+str(s)+'_exp_'+str(exp_num)+'_state_dict.pth'
        print(classic_model_path)
        classic_model.to(device)
        classic_model.load_state_dict(torch.load(classic_model_path))
        print("Model loaded")
        
        # classic model perf
        classic_test_res = th.test(classic_model, device, mnist_test_loader, loss_func=classic_nll_loss_func, verbose=True, pred_func=classic_pred_func)

        # create model to be converted
        fgn_model = th.Feedforward_FGN_net(28*28,10,s).to(device)
        
        # convert
        th.convert_Classic2FGN(classic_model=classic_model, fgn_model=fgn_model)
        print("Model converted")
        
        # perf (check that same or close to above)
        fgn_test_res1 = th.test(fgn_model, device, mnist_test_loader, loss_func=fgn_nll_loss_func, verbose=True, pred_func=fgn_pred_func)
        if fgn_test_res1['test_accuracy'] < 0.99*classic_test_res['test_accuracy']:
            print("Error during conversion")
        else:
            print("Conversion successful")
        
        # half sigma until performance hit
        current_test_res = fgn_test_res1
        while current_test_res['test_accuracy'] > 0.95*fgn_test_res1['test_accuracy']:
            print("Halfing sigma")
            half_sigma(fgn_model)
            current_test_res = th.test(fgn_model, device, mnist_test_loader, loss_func=fgn_nll_loss_func, verbose=True, pred_func=fgn_pred_func)
        # set back 
        print("Doubling Sigma")
        double_sigma(fgn_model)
        current_test_res = th.test(fgn_model, device, mnist_test_loader, loss_func=fgn_nll_loss_func, verbose=True, pred_func=fgn_pred_func)
        # save model
        model_name = "fgn_model_{}_exp_{}".format(str(s), str(exp_num))
        print("Saving converted model {} in {}".format(model_name, save_path))
        # save model entirely
        torch.save(fgn_model, save_path+model_name+"_full.pth")
        
        # save model weights
        torch.save(fgn_model.state_dict(), save_path+model_name+"_state_dict.pth")
               
        print()
# Out:
# Working on size: []
# Working on exp: 0
# ./saved_models/Classic_MNIST_Nets/model_[]_exp_0_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0044, Accuracy: 9198/10000 (92%)
# Model converted
# Test set - Average loss: 0.0044, Accuracy: 9198/10000 (92%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9198/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9198/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9198/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0047, Accuracy: 9198/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0123, Accuracy: 9204/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0347, Accuracy: 9192/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 3686/10000 (37%)
# Doubling Sigma
# Test set - Average loss: 0.0347, Accuracy: 9192/10000 (92%)
# Saving converted model fgn_model_[]_exp_0 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 1
# ./saved_models/Classic_MNIST_Nets/model_[]_exp_1_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0043, Accuracy: 9212/10000 (92%)
# Model converted
# Test set - Average loss: 0.0043, Accuracy: 9213/10000 (92%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0043, Accuracy: 9213/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0043, Accuracy: 9213/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0043, Accuracy: 9212/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0046, Accuracy: 9207/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0123, Accuracy: 9203/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0347, Accuracy: 9184/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 3631/10000 (36%)
# Doubling Sigma
# Test set - Average loss: 0.0347, Accuracy: 9184/10000 (92%)
# Saving converted model fgn_model_[]_exp_1 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 2
# ./saved_models/Classic_MNIST_Nets/model_[]_exp_2_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0043, Accuracy: 9213/10000 (92%)
# Model converted
# Test set - Average loss: 0.0043, Accuracy: 9213/10000 (92%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0043, Accuracy: 9213/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0043, Accuracy: 9213/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0043, Accuracy: 9215/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0046, Accuracy: 9213/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0122, Accuracy: 9216/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0346, Accuracy: 9183/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 3548/10000 (35%)
# Doubling Sigma
# Test set - Average loss: 0.0346, Accuracy: 9183/10000 (92%)
# Saving converted model fgn_model_[]_exp_2 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 3
# ./saved_models/Classic_MNIST_Nets/model_[]_exp_3_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0044, Accuracy: 9232/10000 (92%)
# Model converted
# Test set - Average loss: 0.0044, Accuracy: 9231/10000 (92%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9231/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9231/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9232/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0046, Accuracy: 9234/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0123, Accuracy: 9230/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0347, Accuracy: 9201/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 3582/10000 (36%)
# Doubling Sigma
# Test set - Average loss: 0.0347, Accuracy: 9201/10000 (92%)
# Saving converted model fgn_model_[]_exp_3 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 4
# ./saved_models/Classic_MNIST_Nets/model_[]_exp_4_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0045, Accuracy: 9196/10000 (92%)
# Model converted
# Test set - Average loss: 0.0044, Accuracy: 9196/10000 (92%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9197/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9198/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9198/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0047, Accuracy: 9188/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0122, Accuracy: 9189/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0347, Accuracy: 9141/10000 (91%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 3442/10000 (34%)
# Doubling Sigma
# Test set - Average loss: 0.0347, Accuracy: 9141/10000 (91%)
# Saving converted model fgn_model_[]_exp_4 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 5
# ./saved_models/Classic_MNIST_Nets/model_[]_exp_5_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0045, Accuracy: 9202/10000 (92%)
# Model converted
# Test set - Average loss: 0.0045, Accuracy: 9202/10000 (92%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0045, Accuracy: 9203/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0045, Accuracy: 9203/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0045, Accuracy: 9203/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0048, Accuracy: 9198/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0123, Accuracy: 9188/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0347, Accuracy: 9147/10000 (91%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 3638/10000 (36%)
# Doubling Sigma
# Test set - Average loss: 0.0347, Accuracy: 9147/10000 (91%)
# Saving converted model fgn_model_[]_exp_5 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 6
# ./saved_models/Classic_MNIST_Nets/model_[]_exp_6_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0044, Accuracy: 9221/10000 (92%)
# Model converted
# Test set - Average loss: 0.0044, Accuracy: 9221/10000 (92%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9221/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9220/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9219/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0047, Accuracy: 9218/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0122, Accuracy: 9221/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0347, Accuracy: 9174/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 3578/10000 (36%)
# Doubling Sigma
# Test set - Average loss: 0.0347, Accuracy: 9174/10000 (92%)
# Saving converted model fgn_model_[]_exp_6 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 7
# ./saved_models/Classic_MNIST_Nets/model_[]_exp_7_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0043, Accuracy: 9216/10000 (92%)
# Model converted
# Test set - Average loss: 0.0043, Accuracy: 9216/10000 (92%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0043, Accuracy: 9216/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0043, Accuracy: 9217/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0043, Accuracy: 9215/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0046, Accuracy: 9219/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0122, Accuracy: 9220/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0346, Accuracy: 9146/10000 (91%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 3369/10000 (34%)
# Doubling Sigma
# Test set - Average loss: 0.0346, Accuracy: 9146/10000 (91%)
# Saving converted model fgn_model_[]_exp_7 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 8
# ./saved_models/Classic_MNIST_Nets/model_[]_exp_8_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0044, Accuracy: 9191/10000 (92%)
# Model converted
# Test set - Average loss: 0.0044, Accuracy: 9191/10000 (92%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9191/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9191/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9190/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0047, Accuracy: 9190/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0122, Accuracy: 9198/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0347, Accuracy: 9193/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 3549/10000 (35%)
# Doubling Sigma
# Test set - Average loss: 0.0347, Accuracy: 9193/10000 (92%)
# Saving converted model fgn_model_[]_exp_8 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 9
# ./saved_models/Classic_MNIST_Nets/model_[]_exp_9_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0044, Accuracy: 9207/10000 (92%)
# Model converted
# Test set - Average loss: 0.0044, Accuracy: 9207/10000 (92%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9207/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9206/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0043, Accuracy: 9208/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0046, Accuracy: 9207/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0123, Accuracy: 9212/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0347, Accuracy: 9204/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 3518/10000 (35%)
# Doubling Sigma
# Test set - Average loss: 0.0347, Accuracy: 9204/10000 (92%)
# Saving converted model fgn_model_[]_exp_9 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 10
# ./saved_models/Classic_MNIST_Nets/model_[]_exp_10_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0043, Accuracy: 9221/10000 (92%)
# Model converted
# Test set - Average loss: 0.0043, Accuracy: 9221/10000 (92%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0043, Accuracy: 9221/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0043, Accuracy: 9221/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0043, Accuracy: 9223/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0046, Accuracy: 9223/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0122, Accuracy: 9225/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0347, Accuracy: 9215/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 3539/10000 (35%)
# Doubling Sigma
# Test set - Average loss: 0.0347, Accuracy: 9215/10000 (92%)
# Saving converted model fgn_model_[]_exp_10 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 11
# ./saved_models/Classic_MNIST_Nets/model_[]_exp_11_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0044, Accuracy: 9211/10000 (92%)
# Model converted
# Test set - Average loss: 0.0044, Accuracy: 9211/10000 (92%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9211/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9212/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0044, Accuracy: 9214/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0047, Accuracy: 9217/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0124, Accuracy: 9209/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0347, Accuracy: 9128/10000 (91%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 3510/10000 (35%)
# Doubling Sigma
# Test set - Average loss: 0.0347, Accuracy: 9128/10000 (91%)
# Saving converted model fgn_model_[]_exp_11 in ./saved_models/Retrained_FG_Nets//
#
# Working on size: [8]
# Working on exp: 0
# ./saved_models/Classic_MNIST_Nets/model_[8]_exp_0_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0054, Accuracy: 9053/10000 (91%)
# Model converted
# Test set - Average loss: 0.0056, Accuracy: 9056/10000 (91%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0072, Accuracy: 9059/10000 (91%)
# Halfing sigma
# Test set - Average loss: 0.0221, Accuracy: 9036/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0360, Accuracy: 8394/10000 (84%)
# Doubling Sigma
# Test set - Average loss: 0.0221, Accuracy: 9036/10000 (90%)
# Saving converted model fgn_model_[8]_exp_0 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 1
# ./saved_models/Classic_MNIST_Nets/model_[8]_exp_1_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0052, Accuracy: 9071/10000 (91%)
# Model converted
# Test set - Average loss: 0.0054, Accuracy: 9069/10000 (91%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0070, Accuracy: 9066/10000 (91%)
# Halfing sigma
# Test set - Average loss: 0.0223, Accuracy: 9064/10000 (91%)
# Halfing sigma
# Test set - Average loss: 0.0360, Accuracy: 8562/10000 (86%)
# Doubling Sigma
# Test set - Average loss: 0.0223, Accuracy: 9064/10000 (91%)
# Saving converted model fgn_model_[8]_exp_1 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 2
# ./saved_models/Classic_MNIST_Nets/model_[8]_exp_2_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0056, Accuracy: 8974/10000 (90%)
# Model converted
# Test set - Average loss: 0.0058, Accuracy: 8969/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0073, Accuracy: 8957/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0225, Accuracy: 8924/10000 (89%)
# Halfing sigma
# Test set - Average loss: 0.0360, Accuracy: 8291/10000 (83%)
# Doubling Sigma
# Test set - Average loss: 0.0225, Accuracy: 8924/10000 (89%)
# Saving converted model fgn_model_[8]_exp_2 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 3
# ./saved_models/Classic_MNIST_Nets/model_[8]_exp_3_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0056, Accuracy: 8995/10000 (90%)
# Model converted
# Test set - Average loss: 0.0058, Accuracy: 8992/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0073, Accuracy: 8984/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0220, Accuracy: 8905/10000 (89%)
# Halfing sigma
# Test set - Average loss: 0.0360, Accuracy: 7987/10000 (80%)
# Doubling Sigma
# Test set - Average loss: 0.0220, Accuracy: 8905/10000 (89%)
# Saving converted model fgn_model_[8]_exp_3 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 4
# ./saved_models/Classic_MNIST_Nets/model_[8]_exp_4_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0053, Accuracy: 9057/10000 (91%)
# Model converted
# Test set - Average loss: 0.0056, Accuracy: 9056/10000 (91%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0072, Accuracy: 9060/10000 (91%)
# Halfing sigma
# Test set - Average loss: 0.0225, Accuracy: 9031/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0360, Accuracy: 8686/10000 (87%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 1115/10000 (11%)
# Doubling Sigma
# Test set - Average loss: 0.0360, Accuracy: 8686/10000 (87%)
# Saving converted model fgn_model_[8]_exp_4 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 5
# ./saved_models/Classic_MNIST_Nets/model_[8]_exp_5_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0054, Accuracy: 9007/10000 (90%)
# Model converted
# Test set - Average loss: 0.0057, Accuracy: 9009/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0072, Accuracy: 9014/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0223, Accuracy: 9010/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0360, Accuracy: 8552/10000 (86%)
# Doubling Sigma
# Test set - Average loss: 0.0223, Accuracy: 9010/10000 (90%)
# Saving converted model fgn_model_[8]_exp_5 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 6
# ./saved_models/Classic_MNIST_Nets/model_[8]_exp_6_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0054, Accuracy: 9030/10000 (90%)
# Model converted
# Test set - Average loss: 0.0056, Accuracy: 9030/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0073, Accuracy: 9036/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0226, Accuracy: 9007/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0360, Accuracy: 8166/10000 (82%)
# Doubling Sigma
# Test set - Average loss: 0.0226, Accuracy: 9007/10000 (90%)
# Saving converted model fgn_model_[8]_exp_6 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 7
# ./saved_models/Classic_MNIST_Nets/model_[8]_exp_7_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0057, Accuracy: 8944/10000 (89%)
# Model converted
# Test set - Average loss: 0.0059, Accuracy: 8943/10000 (89%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0075, Accuracy: 8924/10000 (89%)
# Halfing sigma
# Test set - Average loss: 0.0227, Accuracy: 8837/10000 (88%)
# Halfing sigma
# Test set - Average loss: 0.0360, Accuracy: 7037/10000 (70%)
# Doubling Sigma
# Test set - Average loss: 0.0227, Accuracy: 8837/10000 (88%)
# Saving converted model fgn_model_[8]_exp_7 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 8
# ./saved_models/Classic_MNIST_Nets/model_[8]_exp_8_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0057, Accuracy: 8934/10000 (89%)
# Model converted
# Test set - Average loss: 0.0059, Accuracy: 8925/10000 (89%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0074, Accuracy: 8920/10000 (89%)
# Halfing sigma
# Test set - Average loss: 0.0223, Accuracy: 8888/10000 (89%)
# Halfing sigma
# Test set - Average loss: 0.0360, Accuracy: 8328/10000 (83%)
# Doubling Sigma
# Test set - Average loss: 0.0223, Accuracy: 8888/10000 (89%)
# Saving converted model fgn_model_[8]_exp_8 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 9
# ./saved_models/Classic_MNIST_Nets/model_[8]_exp_9_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0055, Accuracy: 9032/10000 (90%)
# Model converted
# Test set - Average loss: 0.0057, Accuracy: 9035/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0073, Accuracy: 9024/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0224, Accuracy: 8979/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0360, Accuracy: 8078/10000 (81%)
# Doubling Sigma
# Test set - Average loss: 0.0224, Accuracy: 8979/10000 (90%)
# Saving converted model fgn_model_[8]_exp_9 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 10
# ./saved_models/Classic_MNIST_Nets/model_[8]_exp_10_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0055, Accuracy: 9012/10000 (90%)
# Model converted
# Test set - Average loss: 0.0057, Accuracy: 9017/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0071, Accuracy: 9021/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0213, Accuracy: 9013/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0359, Accuracy: 8638/10000 (86%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 1575/10000 (16%)
# Doubling Sigma
# Test set - Average loss: 0.0359, Accuracy: 8638/10000 (86%)
# Saving converted model fgn_model_[8]_exp_10 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 11
# ./saved_models/Classic_MNIST_Nets/model_[8]_exp_11_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0053, Accuracy: 9033/10000 (90%)
# Model converted
# Test set - Average loss: 0.0055, Accuracy: 9031/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0071, Accuracy: 9028/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0222, Accuracy: 8978/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0360, Accuracy: 8016/10000 (80%)
# Doubling Sigma
# Test set - Average loss: 0.0222, Accuracy: 8978/10000 (90%)
# Saving converted model fgn_model_[8]_exp_11 in ./saved_models/Retrained_FG_Nets//
#
# Working on size: [128]
# Working on exp: 0
# ./saved_models/Classic_MNIST_Nets/model_[128]_exp_0_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0019, Accuracy: 9642/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9642/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9643/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9643/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0026, Accuracy: 9634/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0101, Accuracy: 9608/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0248, Accuracy: 9360/10000 (94%)
# Halfing sigma
# Test set - Average loss: 0.0339, Accuracy: 4535/10000 (45%)
# Doubling Sigma
# Test set - Average loss: 0.0248, Accuracy: 9360/10000 (94%)
# Saving converted model fgn_model_[128]_exp_0 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 1
# ./saved_models/Classic_MNIST_Nets/model_[128]_exp_1_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9623/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9623/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9623/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9622/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0027, Accuracy: 9614/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0101, Accuracy: 9588/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0247, Accuracy: 9339/10000 (93%)
# Halfing sigma
# Test set - Average loss: 0.0340, Accuracy: 4268/10000 (43%)
# Doubling Sigma
# Test set - Average loss: 0.0247, Accuracy: 9339/10000 (93%)
# Saving converted model fgn_model_[128]_exp_1 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 2
# ./saved_models/Classic_MNIST_Nets/model_[128]_exp_2_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9641/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9641/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9641/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9639/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0026, Accuracy: 9635/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0101, Accuracy: 9611/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0248, Accuracy: 9385/10000 (94%)
# Halfing sigma
# Test set - Average loss: 0.0340, Accuracy: 3875/10000 (39%)
# Doubling Sigma
# Test set - Average loss: 0.0248, Accuracy: 9385/10000 (94%)
# Saving converted model fgn_model_[128]_exp_2 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 3
# ./saved_models/Classic_MNIST_Nets/model_[128]_exp_3_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9634/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9633/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9633/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9631/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0027, Accuracy: 9625/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0102, Accuracy: 9609/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0249, Accuracy: 9375/10000 (94%)
# Halfing sigma
# Test set - Average loss: 0.0340, Accuracy: 4708/10000 (47%)
# Doubling Sigma
# Test set - Average loss: 0.0249, Accuracy: 9375/10000 (94%)
# Saving converted model fgn_model_[128]_exp_3 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 4
# ./saved_models/Classic_MNIST_Nets/model_[128]_exp_4_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0021, Accuracy: 9622/10000 (96%)
# Model converted
# Test set - Average loss: 0.0021, Accuracy: 9621/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9621/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0022, Accuracy: 9620/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0027, Accuracy: 9613/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0103, Accuracy: 9593/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0250, Accuracy: 9350/10000 (94%)
# Halfing sigma
# Test set - Average loss: 0.0339, Accuracy: 4571/10000 (46%)
# Doubling Sigma
# Test set - Average loss: 0.0250, Accuracy: 9350/10000 (94%)
# Saving converted model fgn_model_[128]_exp_4 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 5
# ./saved_models/Classic_MNIST_Nets/model_[128]_exp_5_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9632/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9632/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9632/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9631/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0027, Accuracy: 9626/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0101, Accuracy: 9598/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0247, Accuracy: 9376/10000 (94%)
# Halfing sigma
# Test set - Average loss: 0.0339, Accuracy: 3891/10000 (39%)
# Doubling Sigma
# Test set - Average loss: 0.0247, Accuracy: 9376/10000 (94%)
# Saving converted model fgn_model_[128]_exp_5 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 6
# ./saved_models/Classic_MNIST_Nets/model_[128]_exp_6_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9635/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9635/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9635/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9634/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0027, Accuracy: 9629/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0101, Accuracy: 9604/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0250, Accuracy: 9393/10000 (94%)
# Halfing sigma
# Test set - Average loss: 0.0340, Accuracy: 3661/10000 (37%)
# Doubling Sigma
# Test set - Average loss: 0.0250, Accuracy: 9393/10000 (94%)
# Saving converted model fgn_model_[128]_exp_6 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 7
# ./saved_models/Classic_MNIST_Nets/model_[128]_exp_7_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9621/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9621/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9620/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9619/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0027, Accuracy: 9614/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0104, Accuracy: 9590/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0251, Accuracy: 9362/10000 (94%)
# Halfing sigma
# Test set - Average loss: 0.0340, Accuracy: 3505/10000 (35%)
# Doubling Sigma
# Test set - Average loss: 0.0251, Accuracy: 9362/10000 (94%)
# Saving converted model fgn_model_[128]_exp_7 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 8
# ./saved_models/Classic_MNIST_Nets/model_[128]_exp_8_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9597/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9596/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9596/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9596/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0027, Accuracy: 9590/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0102, Accuracy: 9572/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0250, Accuracy: 9363/10000 (94%)
# Halfing sigma
# Test set - Average loss: 0.0340, Accuracy: 3633/10000 (36%)
# Doubling Sigma
# Test set - Average loss: 0.0250, Accuracy: 9363/10000 (94%)
# Saving converted model fgn_model_[128]_exp_8 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 9
# ./saved_models/Classic_MNIST_Nets/model_[128]_exp_9_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9641/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9641/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9641/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9641/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0027, Accuracy: 9634/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0100, Accuracy: 9596/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0247, Accuracy: 9346/10000 (93%)
# Halfing sigma
# Test set - Average loss: 0.0340, Accuracy: 4052/10000 (41%)
# Doubling Sigma
# Test set - Average loss: 0.0247, Accuracy: 9346/10000 (93%)
# Saving converted model fgn_model_[128]_exp_9 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 10
# ./saved_models/Classic_MNIST_Nets/model_[128]_exp_10_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9640/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9640/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9642/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9641/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0026, Accuracy: 9636/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0102, Accuracy: 9606/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0248, Accuracy: 9378/10000 (94%)
# Halfing sigma
# Test set - Average loss: 0.0340, Accuracy: 3863/10000 (39%)
# Doubling Sigma
# Test set - Average loss: 0.0248, Accuracy: 9378/10000 (94%)
# Saving converted model fgn_model_[128]_exp_10 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 11
# ./saved_models/Classic_MNIST_Nets/model_[128]_exp_11_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9625/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9625/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9625/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9624/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0027, Accuracy: 9617/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0102, Accuracy: 9600/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0247, Accuracy: 9351/10000 (94%)
# Halfing sigma
# Test set - Average loss: 0.0340, Accuracy: 3854/10000 (39%)
# Doubling Sigma
# Test set - Average loss: 0.0247, Accuracy: 9351/10000 (94%)
# Saving converted model fgn_model_[128]_exp_11 in ./saved_models/Retrained_FG_Nets//
#
# Working on size: [1024]
# Working on exp: 0
# ./saved_models/Classic_MNIST_Nets/model_[1024]_exp_0_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9625/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9625/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9624/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9622/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0022, Accuracy: 9608/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0027, Accuracy: 9550/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0095, Accuracy: 9091/10000 (91%)
# Doubling Sigma
# Test set - Average loss: 0.0027, Accuracy: 9550/10000 (96%)
# Saving converted model fgn_model_[1024]_exp_0 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 1
# ./saved_models/Classic_MNIST_Nets/model_[1024]_exp_1_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9616/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9616/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9617/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9613/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9605/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0027, Accuracy: 9560/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0094, Accuracy: 9163/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0342, Accuracy: 4205/10000 (42%)
# Doubling Sigma
# Test set - Average loss: 0.0094, Accuracy: 9163/10000 (92%)
# Saving converted model fgn_model_[1024]_exp_1 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 2
# ./saved_models/Classic_MNIST_Nets/model_[1024]_exp_2_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0019, Accuracy: 9651/10000 (97%)
# Model converted
# Test set - Average loss: 0.0019, Accuracy: 9651/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0019, Accuracy: 9651/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9650/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9629/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0026, Accuracy: 9578/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0092, Accuracy: 9150/10000 (92%)
# Doubling Sigma
# Test set - Average loss: 0.0026, Accuracy: 9578/10000 (96%)
# Saving converted model fgn_model_[1024]_exp_2 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 3
# ./saved_models/Classic_MNIST_Nets/model_[1024]_exp_3_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9631/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9630/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9628/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9627/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9619/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0027, Accuracy: 9552/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0095, Accuracy: 9080/10000 (91%)
# Doubling Sigma
# Test set - Average loss: 0.0027, Accuracy: 9552/10000 (96%)
# Saving converted model fgn_model_[1024]_exp_3 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 4
# ./saved_models/Classic_MNIST_Nets/model_[1024]_exp_4_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9625/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9625/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9625/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9621/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9612/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0025, Accuracy: 9578/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0090, Accuracy: 9240/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0342, Accuracy: 4937/10000 (49%)
# Doubling Sigma
# Test set - Average loss: 0.0090, Accuracy: 9240/10000 (92%)
# Saving converted model fgn_model_[1024]_exp_4 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 5
# ./saved_models/Classic_MNIST_Nets/model_[1024]_exp_5_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9649/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9649/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9649/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9647/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9639/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0025, Accuracy: 9591/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0090, Accuracy: 9199/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0342, Accuracy: 5756/10000 (58%)
# Doubling Sigma
# Test set - Average loss: 0.0090, Accuracy: 9199/10000 (92%)
# Saving converted model fgn_model_[1024]_exp_5 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 6
# ./saved_models/Classic_MNIST_Nets/model_[1024]_exp_6_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0019, Accuracy: 9634/10000 (96%)
# Model converted
# Test set - Average loss: 0.0019, Accuracy: 9634/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0019, Accuracy: 9633/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9631/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9629/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0026, Accuracy: 9591/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0094, Accuracy: 9171/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0342, Accuracy: 5418/10000 (54%)
# Doubling Sigma
# Test set - Average loss: 0.0094, Accuracy: 9171/10000 (92%)
# Saving converted model fgn_model_[1024]_exp_6 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 7
# ./saved_models/Classic_MNIST_Nets/model_[1024]_exp_7_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9623/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9622/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9623/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9621/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9612/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0026, Accuracy: 9556/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0093, Accuracy: 9107/10000 (91%)
# Doubling Sigma
# Test set - Average loss: 0.0026, Accuracy: 9556/10000 (96%)
# Saving converted model fgn_model_[1024]_exp_7 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 8
# ./saved_models/Classic_MNIST_Nets/model_[1024]_exp_8_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9647/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9647/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9644/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9643/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9635/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0026, Accuracy: 9586/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0091, Accuracy: 9172/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0342, Accuracy: 4315/10000 (43%)
# Doubling Sigma
# Test set - Average loss: 0.0091, Accuracy: 9172/10000 (92%)
# Saving converted model fgn_model_[1024]_exp_8 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 9
# ./saved_models/Classic_MNIST_Nets/model_[1024]_exp_9_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9625/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9625/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9625/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9626/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9617/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0026, Accuracy: 9557/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0093, Accuracy: 9145/10000 (91%)
# Halfing sigma
# Test set - Average loss: 0.0342, Accuracy: 4802/10000 (48%)
# Doubling Sigma
# Test set - Average loss: 0.0093, Accuracy: 9145/10000 (91%)
# Saving converted model fgn_model_[1024]_exp_9 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 10
# ./saved_models/Classic_MNIST_Nets/model_[1024]_exp_10_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9642/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9642/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9642/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9639/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9625/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0027, Accuracy: 9562/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0095, Accuracy: 9126/10000 (91%)
# Doubling Sigma
# Test set - Average loss: 0.0027, Accuracy: 9562/10000 (96%)
# Saving converted model fgn_model_[1024]_exp_10 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 11
# ./saved_models/Classic_MNIST_Nets/model_[1024]_exp_11_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0020, Accuracy: 9632/10000 (96%)
# Model converted
# Test set - Average loss: 0.0020, Accuracy: 9632/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9633/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0020, Accuracy: 9631/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9620/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0027, Accuracy: 9562/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0094, Accuracy: 9085/10000 (91%)
# Doubling Sigma
# Test set - Average loss: 0.0027, Accuracy: 9562/10000 (96%)
# Saving converted model fgn_model_[1024]_exp_11 in ./saved_models/Retrained_FG_Nets//
#
# Working on size: [8, 8]
# Working on exp: 0
# ./saved_models/Classic_MNIST_Nets/model_[8, 8]_exp_0_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0056, Accuracy: 9047/10000 (90%)
# Model converted
# Test set - Average loss: 0.0058, Accuracy: 9046/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0072, Accuracy: 9049/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0181, Accuracy: 8944/10000 (89%)
# Halfing sigma
# Test set - Average loss: 0.0367, Accuracy: 892/10000 (9%)
# Doubling Sigma
# Test set - Average loss: 0.0181, Accuracy: 8944/10000 (89%)
# Saving converted model fgn_model_[8, 8]_exp_0 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 1
# ./saved_models/Classic_MNIST_Nets/model_[8, 8]_exp_1_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0058, Accuracy: 8968/10000 (90%)
# Model converted
# Test set - Average loss: 0.0060, Accuracy: 8963/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0076, Accuracy: 8964/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0181, Accuracy: 8922/10000 (89%)
# Halfing sigma
# Test set - Average loss: 0.0362, Accuracy: 894/10000 (9%)
# Doubling Sigma
# Test set - Average loss: 0.0181, Accuracy: 8922/10000 (89%)
# Saving converted model fgn_model_[8, 8]_exp_1 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 2
# ./saved_models/Classic_MNIST_Nets/model_[8, 8]_exp_2_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0059, Accuracy: 9008/10000 (90%)
# Model converted
# Test set - Average loss: 0.0061, Accuracy: 9012/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0077, Accuracy: 9009/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0188, Accuracy: 8990/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0364, Accuracy: 1082/10000 (11%)
# Doubling Sigma
# Test set - Average loss: 0.0188, Accuracy: 8990/10000 (90%)
# Saving converted model fgn_model_[8, 8]_exp_2 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 3
# ./saved_models/Classic_MNIST_Nets/model_[8, 8]_exp_3_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0065, Accuracy: 8885/10000 (89%)
# Model converted
# Test set - Average loss: 0.0067, Accuracy: 8893/10000 (89%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0083, Accuracy: 8881/10000 (89%)
# Halfing sigma
# Test set - Average loss: 0.0188, Accuracy: 8799/10000 (88%)
# Halfing sigma
# Test set - Average loss: 0.0368, Accuracy: 1591/10000 (16%)
# Doubling Sigma
# Test set - Average loss: 0.0188, Accuracy: 8799/10000 (88%)
# Saving converted model fgn_model_[8, 8]_exp_3 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 4
# ./saved_models/Classic_MNIST_Nets/model_[8, 8]_exp_4_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0058, Accuracy: 9003/10000 (90%)
# Model converted
# Test set - Average loss: 0.0061, Accuracy: 9002/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0077, Accuracy: 9002/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0184, Accuracy: 8950/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0363, Accuracy: 1114/10000 (11%)
# Doubling Sigma
# Test set - Average loss: 0.0184, Accuracy: 8950/10000 (90%)
# Saving converted model fgn_model_[8, 8]_exp_4 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 5
# ./saved_models/Classic_MNIST_Nets/model_[8, 8]_exp_5_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0054, Accuracy: 9052/10000 (91%)
# Model converted
# Test set - Average loss: 0.0057, Accuracy: 9051/10000 (91%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0072, Accuracy: 9066/10000 (91%)
# Halfing sigma
# Test set - Average loss: 0.0181, Accuracy: 9017/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0366, Accuracy: 1040/10000 (10%)
# Doubling Sigma
# Test set - Average loss: 0.0181, Accuracy: 9017/10000 (90%)
# Saving converted model fgn_model_[8, 8]_exp_5 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 6
# ./saved_models/Classic_MNIST_Nets/model_[8, 8]_exp_6_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0056, Accuracy: 9045/10000 (90%)
# Model converted
# Test set - Average loss: 0.0058, Accuracy: 9046/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0074, Accuracy: 9056/10000 (91%)
# Halfing sigma
# Test set - Average loss: 0.0179, Accuracy: 8986/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0365, Accuracy: 1032/10000 (10%)
# Doubling Sigma
# Test set - Average loss: 0.0179, Accuracy: 8986/10000 (90%)
# Saving converted model fgn_model_[8, 8]_exp_6 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 7
# ./saved_models/Classic_MNIST_Nets/model_[8, 8]_exp_7_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0064, Accuracy: 8846/10000 (88%)
# Model converted
# Test set - Average loss: 0.0066, Accuracy: 8848/10000 (88%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0081, Accuracy: 8839/10000 (88%)
# Halfing sigma
# Test set - Average loss: 0.0183, Accuracy: 8765/10000 (88%)
# Halfing sigma
# Test set - Average loss: 0.0364, Accuracy: 908/10000 (9%)
# Doubling Sigma
# Test set - Average loss: 0.0183, Accuracy: 8765/10000 (88%)
# Saving converted model fgn_model_[8, 8]_exp_7 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 8
# ./saved_models/Classic_MNIST_Nets/model_[8, 8]_exp_8_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0056, Accuracy: 9016/10000 (90%)
# Model converted
# Test set - Average loss: 0.0058, Accuracy: 9011/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0072, Accuracy: 9012/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0177, Accuracy: 8929/10000 (89%)
# Halfing sigma
# Test set - Average loss: 0.0365, Accuracy: 1170/10000 (12%)
# Doubling Sigma
# Test set - Average loss: 0.0177, Accuracy: 8929/10000 (89%)
# Saving converted model fgn_model_[8, 8]_exp_8 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 9
# ./saved_models/Classic_MNIST_Nets/model_[8, 8]_exp_9_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0054, Accuracy: 9029/10000 (90%)
# Model converted
# Test set - Average loss: 0.0057, Accuracy: 9035/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0072, Accuracy: 9045/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0172, Accuracy: 9024/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0360, Accuracy: 1503/10000 (15%)
# Doubling Sigma
# Test set - Average loss: 0.0172, Accuracy: 9024/10000 (90%)
# Saving converted model fgn_model_[8, 8]_exp_9 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 10
# ./saved_models/Classic_MNIST_Nets/model_[8, 8]_exp_10_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0055, Accuracy: 9009/10000 (90%)
# Model converted
# Test set - Average loss: 0.0057, Accuracy: 9021/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0074, Accuracy: 9045/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0184, Accuracy: 8972/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0367, Accuracy: 1046/10000 (10%)
# Doubling Sigma
# Test set - Average loss: 0.0184, Accuracy: 8972/10000 (90%)
# Saving converted model fgn_model_[8, 8]_exp_10 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 11
# ./saved_models/Classic_MNIST_Nets/model_[8, 8]_exp_11_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0054, Accuracy: 9039/10000 (90%)
# Model converted
# Test set - Average loss: 0.0056, Accuracy: 9041/10000 (90%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0072, Accuracy: 9034/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0177, Accuracy: 8953/10000 (90%)
# Halfing sigma
# Test set - Average loss: 0.0361, Accuracy: 901/10000 (9%)
# Doubling Sigma
# Test set - Average loss: 0.0177, Accuracy: 8953/10000 (90%)
# Saving converted model fgn_model_[8, 8]_exp_11 in ./saved_models/Retrained_FG_Nets//
#
# Working on size: [128, 128]
# Working on exp: 0
# ./saved_models/Classic_MNIST_Nets/model_[128, 128]_exp_0_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0016, Accuracy: 9681/10000 (97%)
# Model converted
# Test set - Average loss: 0.0016, Accuracy: 9681/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0016, Accuracy: 9680/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9677/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0022, Accuracy: 9675/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0074, Accuracy: 9650/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0219, Accuracy: 9349/10000 (93%)
# Halfing sigma
# Test set - Average loss: 0.0338, Accuracy: 3537/10000 (35%)
# Doubling Sigma
# Test set - Average loss: 0.0219, Accuracy: 9349/10000 (93%)
# Saving converted model fgn_model_[128, 128]_exp_0 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 1
# ./saved_models/Classic_MNIST_Nets/model_[128, 128]_exp_1_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0017, Accuracy: 9679/10000 (97%)
# Model converted
# Test set - Average loss: 0.0017, Accuracy: 9679/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9679/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9676/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0022, Accuracy: 9668/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0076, Accuracy: 9626/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0222, Accuracy: 9258/10000 (93%)
# Halfing sigma
# Test set - Average loss: 0.0338, Accuracy: 3616/10000 (36%)
# Doubling Sigma
# Test set - Average loss: 0.0222, Accuracy: 9258/10000 (93%)
# Saving converted model fgn_model_[128, 128]_exp_1 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 2
# ./saved_models/Classic_MNIST_Nets/model_[128, 128]_exp_2_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0016, Accuracy: 9683/10000 (97%)
# Model converted
# Test set - Average loss: 0.0016, Accuracy: 9683/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0016, Accuracy: 9684/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9682/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0022, Accuracy: 9679/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0075, Accuracy: 9649/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0218, Accuracy: 9345/10000 (93%)
# Halfing sigma
# Test set - Average loss: 0.0338, Accuracy: 3380/10000 (34%)
# Doubling Sigma
# Test set - Average loss: 0.0218, Accuracy: 9345/10000 (93%)
# Saving converted model fgn_model_[128, 128]_exp_2 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 3
# ./saved_models/Classic_MNIST_Nets/model_[128, 128]_exp_3_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0017, Accuracy: 9682/10000 (97%)
# Model converted
# Test set - Average loss: 0.0017, Accuracy: 9681/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9680/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9678/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0022, Accuracy: 9668/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0075, Accuracy: 9647/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0218, Accuracy: 9369/10000 (94%)
# Halfing sigma
# Test set - Average loss: 0.0338, Accuracy: 2684/10000 (27%)
# Doubling Sigma
# Test set - Average loss: 0.0218, Accuracy: 9369/10000 (94%)
# Saving converted model fgn_model_[128, 128]_exp_3 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 4
# ./saved_models/Classic_MNIST_Nets/model_[128, 128]_exp_4_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0017, Accuracy: 9684/10000 (97%)
# Model converted
# Test set - Average loss: 0.0017, Accuracy: 9683/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9683/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9680/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0023, Accuracy: 9672/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0077, Accuracy: 9638/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0220, Accuracy: 9277/10000 (93%)
# Halfing sigma
# Test set - Average loss: 0.0339, Accuracy: 2511/10000 (25%)
# Doubling Sigma
# Test set - Average loss: 0.0220, Accuracy: 9277/10000 (93%)
# Saving converted model fgn_model_[128, 128]_exp_4 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 5
# ./saved_models/Classic_MNIST_Nets/model_[128, 128]_exp_5_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0017, Accuracy: 9672/10000 (97%)
# Model converted
# Test set - Average loss: 0.0017, Accuracy: 9672/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9672/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9673/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0022, Accuracy: 9671/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0075, Accuracy: 9643/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0219, Accuracy: 9339/10000 (93%)
# Halfing sigma
# Test set - Average loss: 0.0339, Accuracy: 2909/10000 (29%)
# Doubling Sigma
# Test set - Average loss: 0.0219, Accuracy: 9339/10000 (93%)
# Saving converted model fgn_model_[128, 128]_exp_5 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 6
# ./saved_models/Classic_MNIST_Nets/model_[128, 128]_exp_6_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0017, Accuracy: 9678/10000 (97%)
# Model converted
# Test set - Average loss: 0.0017, Accuracy: 9679/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9679/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9678/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0022, Accuracy: 9668/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0073, Accuracy: 9634/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0213, Accuracy: 9309/10000 (93%)
# Halfing sigma
# Test set - Average loss: 0.0337, Accuracy: 3020/10000 (30%)
# Doubling Sigma
# Test set - Average loss: 0.0213, Accuracy: 9309/10000 (93%)
# Saving converted model fgn_model_[128, 128]_exp_6 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 7
# ./saved_models/Classic_MNIST_Nets/model_[128, 128]_exp_7_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0017, Accuracy: 9696/10000 (97%)
# Model converted
# Test set - Average loss: 0.0017, Accuracy: 9696/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9696/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9695/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0023, Accuracy: 9680/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0078, Accuracy: 9653/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0221, Accuracy: 9276/10000 (93%)
# Halfing sigma
# Test set - Average loss: 0.0338, Accuracy: 2732/10000 (27%)
# Doubling Sigma
# Test set - Average loss: 0.0221, Accuracy: 9276/10000 (93%)
# Saving converted model fgn_model_[128, 128]_exp_7 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 8
# ./saved_models/Classic_MNIST_Nets/model_[128, 128]_exp_8_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0017, Accuracy: 9674/10000 (97%)
# Model converted
# Test set - Average loss: 0.0017, Accuracy: 9674/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9673/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9670/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0022, Accuracy: 9666/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0075, Accuracy: 9642/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0220, Accuracy: 9295/10000 (93%)
# Halfing sigma
# Test set - Average loss: 0.0341, Accuracy: 2986/10000 (30%)
# Doubling Sigma
# Test set - Average loss: 0.0220, Accuracy: 9295/10000 (93%)
# Saving converted model fgn_model_[128, 128]_exp_8 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 9
# ./saved_models/Classic_MNIST_Nets/model_[128, 128]_exp_9_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0016, Accuracy: 9676/10000 (97%)
# Model converted
# Test set - Average loss: 0.0016, Accuracy: 9676/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0016, Accuracy: 9677/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9674/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0021, Accuracy: 9669/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0076, Accuracy: 9647/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0223, Accuracy: 9350/10000 (94%)
# Halfing sigma
# Test set - Average loss: 0.0339, Accuracy: 3857/10000 (39%)
# Doubling Sigma
# Test set - Average loss: 0.0223, Accuracy: 9350/10000 (94%)
# Saving converted model fgn_model_[128, 128]_exp_9 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 10
# ./saved_models/Classic_MNIST_Nets/model_[128, 128]_exp_10_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0016, Accuracy: 9684/10000 (97%)
# Model converted
# Test set - Average loss: 0.0016, Accuracy: 9683/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0016, Accuracy: 9683/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9682/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0022, Accuracy: 9672/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0075, Accuracy: 9656/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0220, Accuracy: 9323/10000 (93%)
# Halfing sigma
# Test set - Average loss: 0.0340, Accuracy: 3274/10000 (33%)
# Doubling Sigma
# Test set - Average loss: 0.0220, Accuracy: 9323/10000 (93%)
# Saving converted model fgn_model_[128, 128]_exp_10 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 11
# ./saved_models/Classic_MNIST_Nets/model_[128, 128]_exp_11_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0017, Accuracy: 9679/10000 (97%)
# Model converted
# Test set - Average loss: 0.0017, Accuracy: 9679/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9679/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9676/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0023, Accuracy: 9670/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0079, Accuracy: 9634/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0224, Accuracy: 9076/10000 (91%)
# Doubling Sigma
# Test set - Average loss: 0.0079, Accuracy: 9634/10000 (96%)
# Saving converted model fgn_model_[128, 128]_exp_11 in ./saved_models/Retrained_FG_Nets//
#
# Working on size: [1024, 1024]
# Working on exp: 0
# ./saved_models/Classic_MNIST_Nets/model_[1024, 1024]_exp_0_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0019, Accuracy: 9641/10000 (96%)
# Model converted
# Test set - Average loss: 0.0019, Accuracy: 9641/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0019, Accuracy: 9641/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0019, Accuracy: 9638/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0019, Accuracy: 9635/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0024, Accuracy: 9593/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0084, Accuracy: 9084/10000 (91%)
# Doubling Sigma
# Test set - Average loss: 0.0024, Accuracy: 9593/10000 (96%)
# Saving converted model fgn_model_[1024, 1024]_exp_0 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 1
# ./saved_models/Classic_MNIST_Nets/model_[1024, 1024]_exp_1_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0017, Accuracy: 9670/10000 (97%)
# Model converted
# Test set - Average loss: 0.0017, Accuracy: 9669/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9668/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9663/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9655/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0023, Accuracy: 9586/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0083, Accuracy: 8934/10000 (89%)
# Doubling Sigma
# Test set - Average loss: 0.0023, Accuracy: 9586/10000 (96%)
# Saving converted model fgn_model_[1024, 1024]_exp_1 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 2
# ./saved_models/Classic_MNIST_Nets/model_[1024, 1024]_exp_2_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0017, Accuracy: 9678/10000 (97%)
# Model converted
# Test set - Average loss: 0.0017, Accuracy: 9678/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9677/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9675/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9664/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0023, Accuracy: 9607/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0084, Accuracy: 8945/10000 (89%)
# Doubling Sigma
# Test set - Average loss: 0.0023, Accuracy: 9607/10000 (96%)
# Saving converted model fgn_model_[1024, 1024]_exp_2 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 3
# ./saved_models/Classic_MNIST_Nets/model_[1024, 1024]_exp_3_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0018, Accuracy: 9668/10000 (97%)
# Model converted
# Test set - Average loss: 0.0018, Accuracy: 9668/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9665/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9663/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9664/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0022, Accuracy: 9626/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0075, Accuracy: 9215/10000 (92%)
# Halfing sigma
# Test set - Average loss: 0.0338, Accuracy: 3276/10000 (33%)
# Doubling Sigma
# Test set - Average loss: 0.0075, Accuracy: 9215/10000 (92%)
# Saving converted model fgn_model_[1024, 1024]_exp_3 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 4
# ./saved_models/Classic_MNIST_Nets/model_[1024, 1024]_exp_4_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0018, Accuracy: 9648/10000 (96%)
# Model converted
# Test set - Average loss: 0.0018, Accuracy: 9648/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9647/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9645/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0019, Accuracy: 9633/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0024, Accuracy: 9553/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0087, Accuracy: 8864/10000 (89%)
# Doubling Sigma
# Test set - Average loss: 0.0024, Accuracy: 9553/10000 (96%)
# Saving converted model fgn_model_[1024, 1024]_exp_4 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 5
# ./saved_models/Classic_MNIST_Nets/model_[1024, 1024]_exp_5_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0017, Accuracy: 9670/10000 (97%)
# Model converted
# Test set - Average loss: 0.0017, Accuracy: 9670/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9670/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9672/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9663/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0022, Accuracy: 9601/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0079, Accuracy: 9109/10000 (91%)
# Doubling Sigma
# Test set - Average loss: 0.0022, Accuracy: 9601/10000 (96%)
# Saving converted model fgn_model_[1024, 1024]_exp_5 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 6
# ./saved_models/Classic_MNIST_Nets/model_[1024, 1024]_exp_6_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0018, Accuracy: 9649/10000 (96%)
# Model converted
# Test set - Average loss: 0.0018, Accuracy: 9649/10000 (96%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9649/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0018, Accuracy: 9644/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0019, Accuracy: 9629/10000 (96%)
# Halfing sigma
# Test set - Average loss: 0.0024, Accuracy: 9546/10000 (95%)
# Halfing sigma
# Test set - Average loss: 0.0090, Accuracy: 8774/10000 (88%)
# Doubling Sigma
# Test set - Average loss: 0.0024, Accuracy: 9546/10000 (95%)
# Saving converted model fgn_model_[1024, 1024]_exp_6 in ./saved_models/Retrained_FG_Nets//
#
# Working on exp: 7
# ./saved_models/Classic_MNIST_Nets/model_[1024, 1024]_exp_7_state_dict.pth
# Model loaded
# Test set - Average loss: 0.0017, Accuracy: 9685/10000 (97%)
# Model converted
# Test set - Average loss: 0.0017, Accuracy: 9685/10000 (97%)
# Conversion successful
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9684/10000 (97%)
# Halfing sigma
# Test set - Average loss: 0.0017, Accuracy: 9683/10000 (97%)
# Halfing sigma
