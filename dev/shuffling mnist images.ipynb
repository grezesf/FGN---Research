# %%
# dev of shuffling mnist samples

# %%
from __future__ import print_function

# %%
import matplotlib as mpl
# set this 'backend' when using jupyter; do this before importing pyplot
mpl.use('nbagg')
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

import numpy as np
import scipy as sp
from scipy import stats
from sklearn import datasets
from sklearn.utils import shuffle as shuffle_in_unison


import sys
sys.path.append('/home/felix/Research/Adversarial Research/FGN---Research/')
import Finite_Gaussian_Network_lib as fgnl
import Finite_Gaussian_Network_lib.fgn_helper_lib as fgnh

# %%
# get mnist train samples
mnist_train_loader, _, _ = fgnh.mnist_dataloaders(batch_size=32)

# %%
data = mnist_train_loader.dataset.tensors[0].numpy()

# %%
# plot 
y = data[0]
print("type:", type(y))
print("shape:", np.shape(y))

plt.imshow(y, cmap=plt.cm.get_cmap('Greys'))
plt.colorbar()
plt.show()
# Out:
# type: <type 'numpy.ndarray'>
# shape: (28, 28)
# <img src="data:image/png;base64,..." width="640">

# %%
random_shuffled_dataloader = fgnh.mnist_random_shuffled_dataloader(num_samples=80000, batch_size=80000)

# %%
# show an example
print("Shape:", random_shuffled_dataloader.dataset.tensors[0].shape)
x = random_shuffled_dataloader.dataset.tensors[0][1]
print(np.sum(x.numpy().flatten()))
print("type:", type(x.numpy()))
print("shape:", x.shape)
# print("sample:", x.numpy())


plt.imshow(x, cmap=plt.cm.get_cmap('Greys'))
plt.colorbar()
plt.show()
# Out:
# Shape: torch.Size([80000, 28, 28])
# 62.452587
# type: <type 'numpy.ndarray'>
# shape: torch.Size([28, 28])
# <img src="data:image/png;base64,..." width="640">

# %%
# show an example
print("Shape:", random_shuffled_dataloader.dataset.tensors[0].shape)
x = random_shuffled_dataloader.dataset.tensors[0][50001]
print(np.sum(x.numpy().flatten()))
print("type:", type(x.numpy()))
print("shape:", x.shape)
# print("sample:", x.numpy())


plt.imshow(x, cmap=plt.cm.get_cmap('Greys'))
plt.colorbar()
plt.show()
# Out:
# Shape: torch.Size([80000, 28, 28])
# 62.45259
# type: <type 'numpy.ndarray'>
# shape: torch.Size([28, 28])
# <img src="data:image/png;base64,..." width="640">
