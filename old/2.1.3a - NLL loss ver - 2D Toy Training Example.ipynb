# %%
# 2D Toy training example
# Goal: examine how the gradients change the center and sigma of a single neuron

# version with NLL loss instead of MSE
# MSE meant I knew the target centers and sigmas were
# but NLL loss works better in general, and will have different dynamics, so worth testing

# %%
from __future__ import print_function

# %%
import matplotlib as mpl
# set this 'backend' when using jupyter; do this before importing pyplot
mpl.use('nbagg')
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

import numpy as np
from scipy import stats

# import sys
# sys.path.append('/home/felix/Research/Adversarial Research/FGN---Research')
import torch_helper_lib as th

# %%
# random seeds
# torch.manual_seed(1665)
# np.random.seed(3266)

# torch.backends.cudnn.deterministic = True
# torch.cuda.manual_seed_all(999)

# %%
# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
use_cuda = True
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")
# Out:
# CUDA Available:  True

# %%
# Define 2d Toy Data

# number of dimensions of the data
num_dim = 2

# gaussian target parameters
data_centers = 1*np.ones(num_dim)
sigma = 1

# hyper-plane separating the classes (this will become the target for the weights)
sep_plane = np.random.uniform(low=-1.0, high=1.0, size=num_dim)
# sep_plane = np.concatenate(([1],np.zeros(num_dim-1)))

num_samples = 1000

samples_xs = np.array([np.random.normal(loc=0, scale=sigma, size=num_dim)+data_centers for _ in range(num_samples)] )

# apply labels based on side of sep hyper plane
# (labels are class number)
samples_labels = np.array([ 0 if x>np.matmul(data_centers, sep_plane) else 1 for x in np.matmul(samples_xs, sep_plane)])

# shuffle in unison
permutation = np.random.permutation(len(samples_xs))
for old_index, new_index in enumerate(permutation):
    samples_xs[new_index] = samples_xs[old_index]
    samples_labels[new_index] = samples_labels[old_index]

# %%
# 2D Check 
samples_x_1 = [x for x,l in zip(samples_xs[:,0], samples_labels) if l==0]
samples_y_1 = [y for y,l in zip(samples_xs[:,1], samples_labels) if l==0]

samples_x_2 = [x for x,l in zip(samples_xs[:,0], samples_labels) if l==1]
samples_y_2 = [y for y,l in zip(samples_xs[:,1], samples_labels) if l==1]


plt.scatter(samples_x_1, samples_y_1)
plt.scatter(samples_x_2, samples_y_2)
plt.grid(True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# convert data to pytorch format 
tensor_x = torch.Tensor(samples_xs)
tensor_y = torch.Tensor(samples_labels)

my_dataset = torch.utils.data.TensorDataset(tensor_x[:num_samples*4/5],tensor_y[:num_samples*4/5]) # create your dataset
my_test_data = torch.utils.data.TensorDataset(tensor_x[num_samples*4/5:],tensor_y[num_samples*4/5:]) # create your dataset

my_dataloader = torch.utils.data.DataLoader(my_dataset, batch_size=32) # create your dataloader
my_test_dataloader = torch.utils.data.DataLoader(my_test_data) # create your dataloader

# %%
# Define a Finite Gaussian Neural Network
class FGNet(nn.Module):
    def __init__(self):
        super(FGNet, self).__init__()
        self.l1 = th.FGN_layer(2,2)

    def forward(self, x):
        x,l = self.l1(x)
        x = F.softmax(x, dim=-1)
        return x,l

# %%
# Initialize the network
model = FGNet().to(device)

# %%
# model stats
print(model)
print([p.size() for p in list(model.parameters())])
print("Training?", model.training) 

# check sizes
print("l1")
print(model.l1.weights.size()) 
print(model.l1.centers.size()) 
print(model.l1.sigs.size())
print(model.l1.pis.size())

# check weights before training
print("l1")
print(model.state_dict())
# Out:
# FGNet(
#   (l1): FGN_layer()
# )
# [torch.Size([2, 2]), torch.Size([2, 2]), torch.Size([2]), torch.Size([2])]
# Training? True
# l1
# torch.Size([2, 2])
# torch.Size([2, 2])
# torch.Size([2])
# torch.Size([2])
# l1
# OrderedDict([('l1.weights', tensor([[-0.5429, -0.3697],
#         [-0.0972, -0.2029]], device='cuda:0')), ('l1.centers', tensor([[-0.0092, -0.0039],
#         [-0.0057, -0.0064]], device='cuda:0')), ('l1.sigs', tensor([1.9916, 1.9953], device='cuda:0')), ('l1.pis', tensor([0.5000, 0.5000], device='cuda:0'))])

# %%
# importances of the constraints
lmbda1 = (4.0*0.1/len(my_dataloader.dataset))
print(lmbda1)
lmbda2 = (1.0/len(my_dataloader.dataset))
print(lmbda2)


# loss function
def loss_func(model, output, target):
    
    # split output into pred and likelihoods
    output, neg_likelihoods = output
    
    # normal NLL loss
    nll_loss = F.nll_loss(output, target.long())
    # sum of sigma squares loss
    sig_loss = lmbda1*torch.abs(model.l1.sigs).pow(2).sum()
    # negative log likelihood over gaussian loss
#     print(neg_likelihoods.shape)
    nllg_loss = torch.sum(neg_likelihoods)
    
    return 1.0*nll_loss + 1.0*sig_loss + 0.0*nllg_loss
# Out:
# 0.0005
# 0.00125

# %%
# number of correct pred function
def pred_func(output, target):
    output,_ = output
    pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
    correct = pred.eq(target.long().view_as(pred)).sum().item()
    return correct

# %%
# model_optimizer
optimizer = optim.SGD(filter(lambda p: p.requires_grad, model.parameters()), lr=0.01, momentum=0.5, nesterov=True)

# %%
epochs = 300
train_res = th.train(model, device, my_dataloader, loss_func, optimizer, epochs, save_hist=2, verbose=True, pred_func=pred_func, test_loader=my_test_dataloader)
# Out:
# Epoch 0 Train set - Average loss: -0.4800, Accuracy: 336/800 (42%)
# Test set - Average loss: -0.4873, Accuracy: 92/200 (46%)
# Epoch 1 Train set - Average loss: -0.4848, Accuracy: 343/800 (43%)
# Test set - Average loss: -0.4920, Accuracy: 92/200 (46%)
# Epoch 2 Train set - Average loss: -0.4895, Accuracy: 355/800 (44%)
# Test set - Average loss: -0.4966, Accuracy: 94/200 (47%)
# Epoch 3 Train set - Average loss: -0.4941, Accuracy: 368/800 (46%)
# Test set - Average loss: -0.5012, Accuracy: 96/200 (48%)
# Epoch 4 Train set - Average loss: -0.4986, Accuracy: 385/800 (48%)
# Test set - Average loss: -0.5057, Accuracy: 99/200 (50%)
# Epoch 5 Train set - Average loss: -0.5032, Accuracy: 397/800 (50%)
# Test set - Average loss: -0.5102, Accuracy: 101/200 (50%)
# Epoch 6 Train set - Average loss: -0.5077, Accuracy: 408/800 (51%)
# Test set - Average loss: -0.5147, Accuracy: 107/200 (54%)
# Epoch 7 Train set - Average loss: -0.5121, Accuracy: 443/800 (55%)
# Test set - Average loss: -0.5191, Accuracy: 114/200 (57%)
# Epoch 8 Train set - Average loss: -0.5166, Accuracy: 494/800 (62%)
# Epoch 139 Train set - Average loss: -0.8670, Accuracy: 778/800 (97%)
# Test set - Average loss: -0.8788, Accuracy: 197/200 (98%)
# Epoch 140 Train set - Average loss: -0.8674, Accuracy: 778/800 (97%)
# Test set - Average loss: -0.8793, Accuracy: 197/200 (98%)
# Epoch 141 Train set - Average loss: -0.8678, Accuracy: 778/800 (97%)
# Test set - Average loss: -0.8797, Accuracy: 197/200 (98%)
# Epoch 142 Train set - Average loss: -0.8682, Accuracy: 778/800 (97%)
# Test set - Average loss: -0.8802, Accuracy: 197/200 (98%)
# Epoch 143 Train set - Average loss: -0.8687, Accuracy: 779/800 (97%)
# Test set - Average loss: -0.8806, Accuracy: 197/200 (98%)
# Epoch 144 Train set - Average loss: -0.8691, Accuracy: 779/800 (97%)
# Test set - Average loss: -0.8811, Accuracy: 197/200 (98%)
# Epoch 145 Train set - Average loss: -0.8695, Accuracy: 781/800 (98%)
# Test set - Average loss: -0.8815, Accuracy: 197/200 (98%)
# Epoch 146 Train set - Average loss: -0.8699, Accuracy: 781/800 (98%)
# Test set - Average loss: -0.8819, Accuracy: 197/200 (98%)
# Epoch 147 Train set - Average loss: -0.8703, Accuracy: 781/800 (98%)
# Test set - Average loss: -0.8824, Accuracy: 197/200 (98%)
# Epoch 148 Train set - Average loss: -0.8707, Accuracy: 783/800 (98%)
# Test set - Average loss: -0.8828, Accuracy: 197/200 (98%)
# Epoch 149 Train set - Average loss: -0.8710, Accuracy: 783/800 (98%)
# Test set - Average loss: -0.8832, Accuracy: 197/200 (98%)
# Epoch 150 Train set - Average loss: -0.8714, Accuracy: 783/800 (98%)
# Test set - Average loss: -0.8836, Accuracy: 197/200 (98%)
# Epoch 151 Train set - Average loss: -0.8718, Accuracy: 783/800 (98%)
# Test set - Average loss: -0.8840, Accuracy: 197/200 (98%)
# Epoch 152 Train set - Average loss: -0.8722, Accuracy: 783/800 (98%)
# Test set - Average loss: -0.8844, Accuracy: 197/200 (98%)
# Epoch 153 Train set - Average loss: -0.8725, Accuracy: 783/800 (98%)
# Test set - Average loss: -0.8848, Accuracy: 197/200 (98%)
# Epoch 154 Train set - Average loss: -0.8729, Accuracy: 783/800 (98%)
# Test set - Average loss: -0.8852, Accuracy: 197/200 (98%)
# Epoch 155 Train set - Average loss: -0.8732, Accuracy: 783/800 (98%)
# Test set - Average loss: -0.8855, Accuracy: 197/200 (98%)
# Epoch 156 Train set - Average loss: -0.8736, Accuracy: 783/800 (98%)
# Test set - Average loss: -0.8859, Accuracy: 198/200 (99%)
# Epoch 157 Train set - Average loss: -0.8739, Accuracy: 784/800 (98%)
# Test set - Average loss: -0.8863, Accuracy: 198/200 (99%)
# Epoch 158 Train set - Average loss: -0.8743, Accuracy: 784/800 (98%)
# Test set - Average loss: -0.8866, Accuracy: 198/200 (99%)
# Epoch 159 Train set - Average loss: -0.8746, Accuracy: 785/800 (98%)
# Test set - Average loss: -0.8870, Accuracy: 198/200 (99%)
# Epoch 160 Train set - Average loss: -0.8749, Accuracy: 785/800 (98%)
# Test set - Average loss: -0.8874, Accuracy: 198/200 (99%)
# Epoch 161 Train set - Average loss: -0.8752, Accuracy: 786/800 (98%)
# Test set - Average loss: -0.8877, Accuracy: 198/200 (99%)
# Epoch 162 Train set - Average loss: -0.8756, Accuracy: 786/800 (98%)
# Test set - Average loss: -0.8881, Accuracy: 198/200 (99%)
# Epoch 163 Train set - Average loss: -0.8759, Accuracy: 786/800 (98%)
# Test set - Average loss: -0.8884, Accuracy: 198/200 (99%)
# Epoch 164 Train set - Average loss: -0.8762, Accuracy: 786/800 (98%)
# Test set - Average loss: -0.8887, Accuracy: 198/200 (99%)
# Epoch 165 Train set - Average loss: -0.8765, Accuracy: 786/800 (98%)
# Test set - Average loss: -0.8891, Accuracy: 198/200 (99%)
# Epoch 166 Train set - Average loss: -0.8768, Accuracy: 786/800 (98%)
# Test set - Average loss: -0.8894, Accuracy: 198/200 (99%)
# Epoch 167 Train set - Average loss: -0.8771, Accuracy: 786/800 (98%)
# Test set - Average loss: -0.8897, Accuracy: 198/200 (99%)
# Epoch 168 Train set - Average loss: -0.8774, Accuracy: 786/800 (98%)
# Test set - Average loss: -0.8900, Accuracy: 198/200 (99%)
# Epoch 169 Train set - Average loss: -0.8777, Accuracy: 786/800 (98%)
# Test set - Average loss: -0.8904, Accuracy: 198/200 (99%)
# Epoch 170 Train set - Average loss: -0.8780, Accuracy: 786/800 (98%)
# Test set - Average loss: -0.8907, Accuracy: 198/200 (99%)
# Epoch 171 Train set - Average loss: -0.8783, Accuracy: 786/800 (98%)
# Test set - Average loss: -0.8910, Accuracy: 198/200 (99%)
# Epoch 172 Train set - Average loss: -0.8786, Accuracy: 787/800 (98%)
# Test set - Average loss: -0.8913, Accuracy: 198/200 (99%)
# Epoch 173 Train set - Average loss: -0.8789, Accuracy: 787/800 (98%)
# Test set - Average loss: -0.8916, Accuracy: 198/200 (99%)
# Epoch 174 Train set - Average loss: -0.8791, Accuracy: 787/800 (98%)
# Test set - Average loss: -0.8919, Accuracy: 198/200 (99%)
# Epoch 175 Train set - Average loss: -0.8794, Accuracy: 787/800 (98%)
# Test set - Average loss: -0.8922, Accuracy: 198/200 (99%)
# Epoch 176 Train set - Average loss: -0.8797, Accuracy: 787/800 (98%)
# Test set - Average loss: -0.8925, Accuracy: 198/200 (99%)
# Epoch 177 Train set - Average loss: -0.8800, Accuracy: 787/800 (98%)
# Test set - Average loss: -0.8928, Accuracy: 198/200 (99%)
# Epoch 178 Train set - Average loss: -0.8802, Accuracy: 787/800 (98%)
# Test set - Average loss: -0.8931, Accuracy: 198/200 (99%)
# Epoch 179 Train set - Average loss: -0.8805, Accuracy: 787/800 (98%)
# Test set - Average loss: -0.8934, Accuracy: 198/200 (99%)
# Epoch 180 Train set - Average loss: -0.8808, Accuracy: 787/800 (98%)
# Test set - Average loss: -0.8936, Accuracy: 198/200 (99%)
# Epoch 181 Train set - Average loss: -0.8810, Accuracy: 787/800 (98%)
# Test set - Average loss: -0.8939, Accuracy: 198/200 (99%)
# Epoch 182 Train set - Average loss: -0.8813, Accuracy: 787/800 (98%)
# Test set - Average loss: -0.8942, Accuracy: 198/200 (99%)
# Epoch 183 Train set - Average loss: -0.8815, Accuracy: 787/800 (98%)
# Test set - Average loss: -0.8945, Accuracy: 198/200 (99%)
# Epoch 184 Train set - Average loss: -0.8818, Accuracy: 788/800 (98%)
# Test set - Average loss: -0
Accuracy: 788/800 (98%)
# Test set - Average loss: -0.9131, Accuracy: 198/200 (99%)
# Epoch 289 Train set - Average loss: -0.8990, Accuracy: 788/800 (98%)
# Test set - Average loss: -0.9132, Accuracy: 198/200 (99%)
# Epoch 290 Train set - Average loss: -0.8991, Accuracy: 788/800 (98%)
# Test set - Average loss: -0.9133, Accuracy: 198/200 (99%)
# Epoch 291 Train set - Average loss: -0.8993, Accuracy: 788/800 (98%)
# Test set - Average loss: -0.9134, Accuracy: 198/200 (99%)
# Epoch 292 Train set - Average loss: -0.8994, Accuracy: 788/800 (98%)
# Test set - Average loss: -0.9136, Accuracy: 198/200 (99%)
# Epoch 293 Train set - Average loss: -0.8995, Accuracy: 788/800 (98%)
# Test set - Average loss: -0.9137, Accuracy: 198/200 (99%)
# Epoch 294 Train set - Average loss: -0.8996, Accuracy: 788/800 (98%)
# Test set - Average loss: -0.9138, Accuracy: 198/200 (99%)
# Epoch 295 Train set - Average loss: -0.8997, Accuracy: 788/800 (98%)
# Test set - Average loss: -0.9139, Accuracy: 198/200 (99%)
# Epoch 296 Train set - Average loss: -0.8998, Accuracy: 788/800 (98%)
# Test set - Average loss: -0.9140, Accuracy: 198/200 (99%)
# Epoch 297 Train set - Average loss: -0.8999, Accuracy: 788/800 (98%)
# Test set - Average loss: -0.9141, Accuracy: 198/200 (99%)
# Epoch 298 Train set - Average loss: -0.9000, Accuracy: 788/800 (98%)
# Test set - Average loss: -0.9142, Accuracy: 198/200 (99%)
# Epoch 299 Train set - Average loss: -0.9001, Accuracy: 788/800 (98%)
# Test set - Average loss: -0.9144, Accuracy: 198/200 (99%)

# %%
# test model, should be same or close to last line in above cell
th.test(model, device, my_test_dataloader, loss_func, verbose=True, pred_func=pred_func)
# Out:
# Test set - Average loss: -0.9144, Accuracy: 198/200 (99%)
# {'test_accuracy': 99.0, 'test_loss': -0.9143527381122112}

# %%
# print model state_dict post training
model.state_dict()
# Out:
# OrderedDict([('l1.weights', tensor([[ 2.4985, -1.9293],
#                       [-4.2549,  1.5463]], device='cuda:0')),
#              ('l1.centers', tensor([[0.7961, 0.7407],
#                       [1.0070, 0.9499]], device='cuda:0')),
#              ('l1.sigs', tensor([2.9913, 3.4320], device='cuda:0')),
#              ('l1.pis', tensor([0.5000, 0.5000], device='cuda:0'))])

# %%
# acc and loss hist
plt.plot(train_res['train_loss_hist'], marker='.', linestyle=' ')
plt.plot(train_res['test_loss_hist'], marker='.', linestyle=' ')
plt.grid()
plt.show()

plt.plot(train_res['train_acc_hist'], marker='.', linestyle=' ')
plt.plot(train_res['test_acc_hist'], marker='.', linestyle=' ')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# compare center with target (1,1)
x, y = zip(*train_res['histories']['l1.centers'][:,0,:])
plt.plot(x,y, marker='.', linestyle='-')
x, y = zip(*train_res['histories']['l1.centers'][:,1,:])
plt.plot(x,y, marker='.', linestyle='-')
# plt.axis([-3,3, -3, 3])
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plot sigma history
plt.plot(train_res['histories']['l1.sigs'][:,0], marker='.', linestyle=' ')
plt.plot(train_res['histories']['l1.sigs'][:,1], marker='.', linestyle=' ')

plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

# %%
# plot softmax(PIs) history

# unormalized
plt.plot(train_res['histories']['l1.pis'][:,0], marker='.', linestyle=' ')
plt.plot(train_res['histories']['l1.pis'][:,1], marker='.', linestyle=' ')

plt.grid()
plt.show()

#normalized 
normalized_PIs = np.array([softmax(x) for x in train_res['histories']['l1.pis']])
plt.plot(normalized_PIs[:,0], marker='.', linestyle=' ')
plt.plot(normalized_PIs[:,1], marker='.', linestyle=' ')

plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
