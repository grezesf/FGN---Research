# %%
# N-Dimensional Toy training example
# Goal: expand 2.1.3a to multiple dimensions
# Conclusion: centers properly, but sigma dynamics still not clear
# sigma init: probably close to sqrt(in_feats)

# %%
from __future__ import print_function

# %%
import matplotlib as mpl
# set this 'backend' when using jupyter; do this before importing pyplot
mpl.use('nbagg')
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

import numpy as np
from scipy import stats

# graph viz tool
# import sys
# sys.path.append('/home/felix/Research/Adversarial Research/FGN---Research')
import torch_helper_lib as th
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 2, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)

# %%
# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
torch.manual_seed(666)
use_cuda = False
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")
# Out:
# CUDA Available:  True

# %%
# Define ND Toy Data

# number of dimensions of the data
num_dim = 25

# gaussian target parameters
data_centers = 0*np.ones(num_dim)
sigma = 1

# hyper-plane separating the classes (this will become the target for the weights)
sep_plane = np.random.uniform(low=-1.0, high=1.0, size=num_dim)
# sep_plane = np.concatenate(([1],np.zeros(num_dim-1)))

num_samples = 50000

samples_xs = np.array([np.random.normal(loc=0, scale=sigma, size=num_dim)+data_centers for _ in range(num_samples)] )

# apply labels based on side of sep hyper plane
samples_labels = np.array([ [1] if (x)>np.matmul(data_centers, sep_plane) else [-1] for x in np.matmul(samples_xs, sep_plane)])

# %%
# 2D Check 
samples_x_1 = [x for x,l in zip(samples_xs[:,0], samples_labels) if l==1]
samples_y_1 = [y for y,l in zip(samples_xs[:,1], samples_labels) if l==1]

samples_x_2 = [x for x,l in zip(samples_xs[:,0], samples_labels) if l==-1]
samples_y_2 = [y for y,l in zip(samples_xs[:,1], samples_labels) if l==-1]


plt.scatter(samples_x_1, samples_y_1)
plt.scatter(samples_x_2, samples_y_2)
plt.grid(True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 3D Check
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# class 1
xs = [x for x,l in zip(samples_xs[:,0], samples_labels) if l==1]
ys = [y for y,l in zip(samples_xs[:,1], samples_labels) if l==1]
zs = [z for z,l in zip(samples_xs[:,2], samples_labels) if l==1]

ax.scatter(xs, ys, zs)

#  class -1
xs = [x for x,l in zip(samples_xs[:,0], samples_labels) if l==-1]
ys = [y for y,l in zip(samples_xs[:,1], samples_labels) if l==-1]
zs = [z for z,l in zip(samples_xs[:,2], samples_labels) if l==-1]

ax.scatter(xs, ys, zs)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# convert data to pytorch format 
tensor_x = torch.Tensor(samples_xs)
tensor_y = torch.Tensor(samples_labels)
# tensor_x = torch.stack([torch.Tensor(i) for i in zip(samples_x, samples_y)]) # transform to torch tensors
# tensor_y = torch.stack([torch.Tensor(i) for i in samples_labels])

my_dataset = torch.utils.data.TensorDataset(tensor_x[:num_samples*4/5],tensor_y[:num_samples*4/5]) # create your dataset
my_test_data = torch.utils.data.TensorDataset(tensor_x[num_samples*4/5:],tensor_y[num_samples*4/5:]) # create your dataset

my_dataloader = torch.utils.data.DataLoader(my_dataset, batch_size=256) # create your dataloader
my_test_dataloader = torch.utils.data.DataLoader(my_test_data) # create your dataloader

# %%
# define the FGN layer class

###
# HARDCODED to be off center but not too far
### 

import math 

class FGN_layer(nn.Module):
    r""" Applies a Finite Gaussian Neuron layer to the incoming data
    
    Args:
    
    Shape:
    
    Attributes:
    
    Examples:
        
        >>> l=FGN_layer(20,30)
    
    """
    def __init__(self, in_features, out_features):
        super(FGN_layer, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        
        # learnable parameters
        # regular NN weights (transposed at the start, see order of Tensor(dims))
        self.weights = nn.Parameter(torch.Tensor(out_features, in_features), requires_grad= True)
        # centers of FGNs
        self.centers = nn.Parameter(torch.Tensor(out_features, in_features), requires_grad = True)
        # size of FGNs
        self.sigs = nn.Parameter(torch.Tensor(out_features,), requires_grad = True)
        
        # parameter init call
        self.reset_parameters()
    
    # parameter init definition
    def reset_parameters(self):
        s = np.sqrt(self.in_features)
        # regular NN init
        self.weights.data.uniform_(-s, s)
        # centers init
        self.centers.data.uniform_(-1, -1)
        # size init
        self.sigs.data.uniform_(self.in_features, self.in_features)
        
    def forward(self, input):
        
        # linear part is the same as normal NNs
        l = nn.functional.linear(input, self.weights, bias=None)
        # optional, apply tanh here
        # l = torch.tanh(l)
#         print("size of L", l.size())
#         print(l)


        # gaussian component
        # unsqueeze the inputs to allow broadcasting
        # compute distance to centers
        g = (input.unsqueeze(1)-self.centers)**2
#         print("size of G", g.size())
#         print(g)
        g = g.sum(dim=2)
#         print("size of G", g.size())

        # for future, use any norm?
#         g = torch.norm(input.unsqueeze(1)-self.centers, p=1, dim=2)

        # apply sigma
        g = -g/(self.sigs**2)
#         print("size of G", g.size())
        # apply exponential
        g = torch.exp(g)
#         print("size of G", g.size())

        # combine gaussian with linear
        res = l*g
        # optional, flatten res
        # res = F.tanh(res)
#         print("size of L*G", res.size())

        # clip res to +1
        res  = torch.clamp(res, min=-1.0, max=1.0)
        
        
        return res

# %%
# Define a (very specific) Finite Gaussian Neural Network

class FGNet(nn.Module):
    def __init__(self):
        super(FGNet, self).__init__()
        self.l1 = FGN_layer(num_dim,1)
        
#         test with only linear classifier
#         self.l1= nn.Linear(num_dim,1)

    def forward(self, x):
        # input: tensor of batch (batchsize, (num_dims))
#         print(x.shape)
        x = self.l1(x)
#         print(x.shape) 
#         x = x.view(1)

        return x

# %%
# Initialize the network
model = FGNet().to(device)

# %%
# model stats
print(model)
print([p.size() for p in list(model.parameters())])
print("Training?", model.training) 

# check sizes
print("l1")
print(model.l1.weights.size()) 
print(model.l1.centers.size()) 
print(model.l1.sigs.size())

# check weights before training
print("l1")
print(model.l1.weights.view(-1).cpu().detach().numpy()[0:4])
print(model.l1.centers.view(-1).cpu().detach().numpy()[0:4])
print(model.l1.sigs.view(-1).cpu().detach().numpy()[0:4])
# Out:
# FGNet(
#   (l1): FGN_layer()
# )
# [torch.Size([1, 25]), torch.Size([1, 25]), torch.Size([1])]
# Training? True
# l1
# torch.Size([1, 25])
# torch.Size([1, 25])
# torch.Size([1])
# l1
# [-1.8809628 -2.298659  -3.8821907 -3.9880955]
# [-1. -1. -1. -1.]
# [25.]

# %%
def train(model, device, train_loader, optimizer, epoch):
    
    # values to return
    weights =  []
    centers = []
    sigmas = []
    weights.append(list(model.l1.weights.view(-1).cpu().detach().numpy()))
    centers.append(list(model.l1.centers.view(-1).cpu().detach().numpy()))
    sigmas.append(list(model.l1.sigs.view(-1).cpu().detach().numpy()))
    
    losses = th.AverageMeter()
    correct = 0
    
    # set model to trainable mode
    model.train()
    # load a batch
    for batch_idx, (data, target) in enumerate(train_loader):
#         print(data,target)
        # load batch data, targets to device
        data, target = data.to(device), target.to(device)
        # reset optimizer gradients
        optimizer.zero_grad()
        # compute predictions
        output = model(data)
#         print(output)
        # compute loss
        loss = F.mse_loss(output, target.float())
        # print(loss)
        
        # update rolling average loss
        losses.update(loss.item(), data.size(0) )
        # update predictions
        pred = torch.Tensor.sign(output)
        correct += pred.eq(target.view_as(pred)).sum().item()        
        
        # propagate gradients
        loss.backward()
#         print("max grad centers:", torch.max(model.l1.centers.grad) )
#         print("max grad sigs:", torch.max(model.l1.sigs.grad) )

        # apply stored gradients to parameters
        optimizer.step()
        
        # print batch stats
#         if batch_idx % (num_samples/5) == 0:
#             print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
#                 epoch, batch_idx * len(data), len(train_loader.dataset),
#                 100. * batch_idx / len(train_loader), loss.item()))
#             print("batch:", batch_idx, " Loss", losses.avg)
    
        weights.append(list(model.l1.weights.view(-1).cpu().detach().numpy()))
        centers.append(list(model.l1.centers.view(-1).cpu().detach().numpy()))
        sigmas.append(list(model.l1.sigs.view(-1).cpu().detach().numpy()))
        
        
    print('Train set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        losses.avg, correct, len(train_loader.dataset),
        100. * correct / len(train_loader.dataset)))

    return(weights, centers, sigmas)

def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.mse_loss(output, target.float())
            pred = torch.Tensor.sign(output)
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
# training params 
optimizer = optim.SGD(filter(lambda p: p.requires_grad, model.parameters()), lr=0.01, momentum=0.5, weight_decay=0.01)

# values to observes
weights_per_update =  []
centers_per_update = []
sigmas_per_update = []

# %%
# train the model 


for epoch in range(1, 500):
    print("Epoch:", epoch)
    weights, centers, sigmas = train(model, device, my_dataloader, optimizer, epoch)
    weights_per_update+=weights
    centers_per_update+=centers
    sigmas_per_update+=sigmas
    
    test(model, device, my_test_dataloader)
# Out:
# Epoch: 1
# Train set: Average loss: 1.6328, Accuracy: 23326/40000 (58%)
# Test set: Average loss: 1.6412, Accuracy: 5775/10000 (58%)
# Epoch: 2
# Train set: Average loss: 1.6071, Accuracy: 23530/40000 (59%)
# Test set: Average loss: 1.6132, Accuracy: 5854/10000 (59%)
# Epoch: 3
# Train set: Average loss: 1.5794, Accuracy: 23781/40000 (59%)
# Test set: Average loss: 1.5824, Accuracy: 5930/10000 (59%)
# Epoch: 4
# Train set: Average loss: 1.5490, Accuracy: 24043/40000 (60%)
# Test set: Average loss: 1.5470, Accuracy: 6016/10000 (60%)
# Epoch: 5
# Train set: Average loss: 1.5161, Accuracy: 24344/40000 (61%)
# Test set: Average loss: 1.5113, Accuracy: 6106/10000 (61%)
# Epoch: 6
# Train set: Average loss: 1.4827, Accuracy: 24695/40000 (62%)
# Test set: Average loss: 1.4742, Accuracy: 6182/10000 (62%)
# Epoch: 7
# Train set: Average loss: 1.4482, Accuracy: 25035/40000 (63%)
# Test set: Average loss: 1.4366, Accuracy: 6278/10000 (63%)
# Epoch: 8
# Train set: Average loss: 1.4122, Accuracy: 25373/40000 (63%)
# Test set: Average loss: 1.3971, Accuracy: 6388/10000 (64%)
# Epoch: 9
# Train set: Average loss: 1.3737, Accuracy: 25762/40000 (64%)
# Test set: Average loss: 1.3578, Accuracy: 6491/10000 (65%)
# Epoch: 10
# Train set: Average loss: 1.3319, Accuracy: 26156/40000 (65%)
# Test set: Average loss: 1.3142, Accuracy: 6593/10000 (66%)
# Epoch: 11
# Train set: Average loss: 1.2861, Accuracy: 26578/40000 (66%)
# Test set: Average loss: 1.2679, Accuracy: 6702/10000 (67%)
# Epoch: 12
# Train set: Average loss: 1.2362, Accuracy: 27052/40000 (68%)
# Test set: Average loss: 1.2184, Accuracy: 6819/10000 (68%)
# Epoch: 13
# Train set: Average loss: 1.1809, Accuracy: 27584/40000 (69%)
# Test set: Average loss: 1.1676, Accuracy: 6939/10000 (69%)
# Epoch: 14
# Train set: Average loss: 1.1233, Accuracy: 28161/40000 (70%)
# Test set: Average loss: 1.1108, Accuracy: 7079/10000 (71%)
# Epoch: 15
# Train set: Average loss: 1.0619, Accuracy: 28776/40000 (72%)
# Test set: Average loss: 1.0525, Accuracy: 7219/10000 (72%)
# Epoch: 16
# Train set: Average loss: 0.9996, Accuracy: 29382/40000 (73%)
# Test set: Average loss: 0.9888, Accuracy: 7357/10000 (74%)
# Epoch: 17
# Train set: Average loss: 0.9324, Accuracy: 30057/40000 (75%)
# Test set: Average loss: 0.9187, Accuracy: 7530/10000 (75%)
# Epoch: 18
# Train set: Average loss: 0.8595, Accuracy: 30731/40000 (77%)
# Test set: Average loss: 0.8433, Accuracy: 7705/10000 (77%)
# Epoch: 19
# Train set: Average loss: 0.7821, Accuracy: 31464/40000 (79%)
# Test set: Average loss: 0.7564, Accuracy: 7912/10000 (79%)
# Epoch: 20
# Train set: Average loss: 0.6961, Accuracy: 32302/40000 (81%)
# Test set: Average loss: 0.6630, Accuracy: 8148/10000 (81%)
# Epoch: 21
# Train set: Average loss: 0.6051, Accuracy: 33184/40000 (83%)
# Test set: Average loss: 0.5697, Accuracy: 8371/10000 (84%)
# Epoch: 22
# Train set: Average loss: 0.5089, Accuracy: 34173/40000 (85%)
# Test set: Average loss: 0.4702, Accuracy: 8621/10000 (86%)
# Epoch: 23
# Train set: Average loss: 0.4087, Accuracy: 35157/40000 (88%)
# Test set: Average loss: 0.3652, Accuracy: 8881/10000 (89%)
# Epoch: 24
# Train set: Average loss: 0.3057, Accuracy: 36186/40000 (90%)
# Test set: Average loss: 0.2592, Accuracy: 9163/10000 (92%)
# Epoch: 25
# Train set: Average loss: 0.2062, Accuracy: 37291/40000 (93%)
# Test set: Average loss: 0.1652, Accuracy: 9450/10000 (94%)
# Epoch: 26
# Train set: Average loss: 0.1230, Accuracy: 38282/40000 (96%)
# Test set: Average loss: 0.0983, Accuracy: 9665/10000 (97%)
# Epoch: 27
# Train set: Average loss: 0.0781, Accuracy: 39041/40000 (98%)
# Test set: Average loss: 0.0697, Accuracy: 9822/10000 (98%)
# Epoch: 28
# Train set: Average loss: 0.0640, Accuracy: 39468/40000 (99%)
# Test set: Average loss: 0.0626, Accuracy: 9910/10000 (99%)
# Epoch: 29
# Train set: Average loss: 0.0619, Accuracy: 39699/40000 (99%)
# Test set: Average loss: 0.0621, Accuracy: 9944/10000 (99%)
# Epoch: 30
# Train set: Average loss: 0.0631, Accuracy: 39838/40000 (100%)
# Test set: Average loss: 0.0637, Accuracy: 9963/10000 (100%)
# Epoch: 31
# Train set: Average loss: 0.0653, Accuracy: 39881/40000 (100%)
# Test set: Average loss: 0.0660, Accuracy: 9973/10000 (100%)
# Epoch: 32
# Train set: Average loss: 0.0679, Accuracy: 39898/40000 (100%)
# Test set: Average loss: 0.0687, Accuracy: 9974/10000 (100%)
# Epoch: 33
# Train set: Average loss: 0.0707, Accuracy: 39900/40000 (100%)
# Test set: Average loss: 0.0716, Accuracy: 9977/10000 (100%)
# Epoch: 34
# Train set: Average loss: 0.0736, Accuracy: 39900/40000 (100%)
# Test set: Average loss: 0.0746, Accuracy: 9975/10000 (100%)
# Epoch: 35
# Train set: Average loss: 0.0766, Accuracy: 39897/40000 (100%)
# Test set: Average loss: 0.0777, Accuracy: 9974/10000 (100%)
# Epoch: 36
# Train set: Average loss: 0.0798, Accuracy: 39897/40000 (100%)
# Test set: Average loss: 0.0810, Accuracy: 9972/10000 (100%)
# Epoch: 37
# Train set: Average loss: 0.0831, Accuracy: 39894/40000 (100%)
# Test set: Average loss: 0.0844, Accuracy: 9972/10000 (100%)
# Epoch: 38
# Train set: Average loss: 0.0865, Accuracy: 39891/40000 (100%)
# Test set: Average loss: 0.0880, Accuracy: 9972/10000 (100%)
# Epoch: 39
# Train set: Average loss: 0.0900, Accuracy: 39885/40000 (100%)
# Test set: Average loss: 0.0916, Accuracy: 9972/10000 (100%)
# Epoch: 40
# Train set: Average loss: 0.0937, Accuracy: 39881/40000 (100%)
# Test set: Average loss: 0.0953, Accuracy: 9972/10000 (100%)
# Epoch: 41
# Train set: Average loss: 0.0974, Accuracy: 39878/40000 (100%)
# Test set: Average loss: 0.0992, Accuracy: 9970/10000 (100%)
# Epoch: 42
# Train set: Average loss: 0.1012, Accuracy: 39878/40000 (100%)
# Test set: Average loss: 0.1031, Accuracy: 9971/10000 (100%)
# Epoch: 43
# Train set: Average loss: 0.1051, Accuracy: 39876/40000 (100%)
# Test set: Average loss: 0.1070, Accuracy: 9968/10000 (100%)
# Epoch: 44
# Train set: Average loss: 0.1090, Accuracy: 39874/40000 (100%)
# Test set: Average loss: 0.1109, Accuracy: 9969/10000 (100%)
# Epoch: 45
# Train set: Average loss: 0.1129, Accuracy: 39871/40000 (100%)
# Test set: Average loss: 0.1149, Accuracy: 9968/10000 (100%)
# Epoch: 46
# Train set: Average loss: 0.1168, Accuracy: 39869/40000 (100%)
# Test set: Average loss: 0.1187, Accuracy: 9968/10000 (100%)
# Epoch: 47
# Train set: Average loss: 0.1206, Accuracy: 39869/40000 (100%)
# Test set: Average loss: 0.1225, Accuracy: 9966/10000 (100%)
# Epoch: 48
# Train set: Average loss: 0.1244, Accuracy: 39868/40000 (100%)
# Test set: Average loss: 0.1262, Accuracy: 9965/10000 (100%)
# Epoch: 49
# Train set: Average loss: 0.1280, Accuracy: 39866/40000 (100%)
# Test set: Average loss: 0.1297, Accuracy: 9965/10000 (100%)
# Epoch: 50
# Train set: Average loss: 0.1314, Accuracy: 39863/40000 (100%)
# Test set: Average loss: 0.1331, Accuracy: 9964/10000 (100%)
# Epoch: 51
# Train set: Average loss: 0.1346, Accuracy: 39862/40000 (100%)
# Test set: Average loss: 0.1362, Accuracy: 9964/10000 (100%)
# Epoch: 52
# Train set: Average loss: 0.1376, Accuracy: 39860/40000 (100%)
# Test set: Average loss: 0.1391, Accuracy: 9964/10000 (100%)
# Epoch: 53
# Train set: Average loss: 0.1403, Accuracy: 39858/40000 (100%)
# Test set: Average loss: 0.1417, Accuracy: 9966/10000 (100%)
# Epoch: 54
# Train set: Average loss: 0.1429, Accuracy: 39858/40000 (100%)
# Test set: Average loss: 0.1441, Accuracy: 9965/10000 (100%)
# Epoch: 55
# Train set: Average loss: 0.1451, Accuracy: 39854/40000 (100%)
# Test set: Average loss: 0.1463, Accuracy: 9965/10000 (100%)
# Epoch: 56
# Train set: Average loss: 0.1472, Accuracy: 39851/40000 (100%)
# Test set: Average loss: 0.1482, Accuracy: 9965/10000 (100%)
# Epoch: 57
# Train set: Average loss: 0.1490, Accuracy: 39851/40000 (100%)
# Test set: Average loss: 0.1499, Accuracy: 9965/10000 (100%)
# Epoch: 58
# Train set: Average loss: 0.1505, Accuracy: 39850/40000 (100%)
# Test set: Average loss: 0.1513, Accuracy: 9965/10000 (100%)
# Epoch: 59
# Train set: Average loss: 0.1519, Accuracy: 39850/40000 (100%)
# Test set: Average loss: 0.1526, Accuracy: 9965/10000 (100%)
# Epoch: 60
# Train set: Average loss: 0.1531, Accuracy: 39852/40000 (100%)
# Test set: Average loss: 0.1537, Accuracy: 9964/10000 (100%)
# Epoch: 61
# Train set: Average loss: 0.1541, Accuracy: 39853/40000 (100%)
# Test set: Average loss: 0.1546, Accuracy: 9964/10000 (100%)
# Epoch: 62
# Train set: Average loss: 0.1549, Accuracy: 39852/40000 (100%)
# Test set: Average loss: 0.1554, Accuracy: 9964/10000 (100%)
# Epoch: 63
# Train set: Average loss: 0.1557, Accuracy: 39850/40000 (100%)
# Test set: Average loss: 0.1560, Accuracy: 9963/10000 (100%)
# Epoch: 64
# Train set: Average loss: 0.1563, Accuracy: 39850/40000 (100%)
# Test set: Average loss: 0.1566, Accuracy: 9963/10000 (100%)
# Epoch: 65
# Train set: Average loss: 0.1568, Accuracy: 39850/40000 (100%)
# Test set: Average loss: 0.1571, Accuracy: 9962/10000 (100%)
# Epoch: 66
# Train set: Average loss: 0.1572, Accuracy: 39849/40000 (100%)
# Test set: Average loss: 0.1574, Accuracy: 9962/10000 (100%)
# Epoch: 67
# Train set: Average loss: 0.1576, Accuracy: 39849/40000 (100%)
# Test set: Average loss: 0.1578, Accuracy: 9962/10000 (100%)
# Epoch: 68
# Train set: Average loss: 0.1579, Accuracy: 39849/40000 (100%)
# Test set: Average loss: 0.1580, Accuracy: 9962/10000 (100%)
# Epoch: 69
# Train set: Average loss: 0.1581, Accuracy: 39849/40000 (100%)
# Test set: Average loss: 0.1583, Accuracy: 9962/10000 (100%)
# Epoch: 70
# Train set: Average loss: 0.1583, Accuracy: 39849/40000 (100%)
# Test set: Average loss: 0.1584, Accuracy: 9962/10000 (100%)
# Epoch: 71
# Train set: Average loss: 0.1585, Accuracy: 39849/40000 (100%)
# Test set: Average loss: 0.1586, Accuracy: 9962/10000 (100%)
# Epoch: 72
# Train set: Average loss: 0.1586, Accuracy: 39849/40000 (100%)
# Test set: Average loss: 0.1587, Accuracy: 9962/10000 (100%)
# Epoch: 73
# Train set: Average loss: 0.1587, Accuracy: 39849/40000 (100%)
# Test set: Average loss: 0.1588, Accuracy: 9961/10000 (100%)
# Epoch: 74
# Train set: Average loss: 0.1588, Accuracy: 39848/40000 (100%)
# Test set: Average loss: 0.1589, Accuracy: 9961/10000 (100%)
# Epoch: 75
# Train set: Average loss: 0.1589, Accuracy: 39848/40000 (100%)
# Test set: Average loss: 0.1589, Accuracy: 9961/10000 (100%)
# Epoch: 76
# Train set: Average loss: 0.1590, Accuracy: 39848/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 77
# Train set: Average loss: 0.1590, Accuracy: 39848/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 78
# Train set: Average loss: 0.1590, Accuracy: 39848/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 79
# Train set: Average loss: 0.1591, Accuracy: 39848/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9961/10000 (100%)
# Epoch: 80
# Train set: Average loss: 0.1591, Accuracy: 39848/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 81
# Train set: Average loss: 0.1591, Accuracy: 39848/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 82
# Train set: Average loss: 0.1591, Accuracy: 39848/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 83
# Train set: Average loss: 0.1591, Accuracy: 39848/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 84
# Train set: Average loss: 0.1591, Accuracy: 39848/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 85
# Train set: Average loss: 0.1591, Accuracy: 39846/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 86
# Train set: Average loss: 0.1591, Accuracy: 39846/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 87
# Train set: Average loss: 0.1591, Accuracy: 39846/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 88
# Train set: Average loss: 0.1591, Accuracy: 39846/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 89
# Train set: Average loss: 0.1591, Accuracy: 39846/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 90
# Train set: Average loss: 0.1591, Accuracy: 39846/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 91
# Train set: Average loss: 0.1591, Accuracy: 39846/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 92
# Train set: Average loss: 0.1591, Accuracy: 39846/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 93
# Train set: Average loss: 0.1591, Accuracy: 39846/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 94
# Train set: Average loss: 0.1591, Accuracy: 39846/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 95
# Train set: Average loss: 0.1591, Accuracy: 39846/40000 (100%)
# Test set: Average loss: 0.1591, Accuracy: 9962/10000 (100%)
# Epoch: 96
# Train set: Average loss: 0.1591, Accuracy: 39846/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 97
# Train set: Average loss: 0.1591, Accuracy: 39846/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 98
# Train set: Average loss: 0.1591, Accuracy: 39846/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 99
# Train set: Average loss: 0.1591, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 100
# Train set: Average loss: 0.1591, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 101
# Train set: Average loss: 0.1591, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 102
# Train set: Average loss: 0.1591, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 103
# Train set: Average loss: 0.1591, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 104
# Train set: Average loss: 0.1591, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 105
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 106
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 107
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 108
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 109
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 110
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 111
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 112
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 113
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 114
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 115
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 116
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 117
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 118
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 119
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 120
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 121
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 122
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 123
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 124
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9962/10000 (100%)
# Epoch: 125
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 126
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 127
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 128
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 129
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 130
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 131
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 132
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 133
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 134
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 135
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 136
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 137
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 138
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 139
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 140
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 141
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 142
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 143
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 144
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 145
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 146
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 147
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 148
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 149
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 150
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 151
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 152
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 153
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 154
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 155
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 156
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 157
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 158
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 159
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 160
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 161
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 162
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 163
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 164
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 165
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 166
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 167
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 168
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 169
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 170
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 171
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 172
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 173
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 174
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 175
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 176
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 177
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 178
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 179
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 180
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 181
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 182
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 183
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 184
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 185
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 186
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 187
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 188
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 189
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 190
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 191
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 192
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 193
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 194
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 195
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 196
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 197
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 198
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 199
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 200
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 201
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 202
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 203
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 204
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 205
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 206
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 207
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 208
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 209
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 210
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 211
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 212
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 213
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 214
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 215
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 216
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 217
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 218
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 219
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 220
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 221
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 222
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 223
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 224
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 225
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 226
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 227
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 228
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 229
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 230
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 231
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 232
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 233
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 234
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 235
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 236
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 237
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 238
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 239
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 240
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 241
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 242
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 243
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 244
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 245
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 246
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 247
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 248
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 249
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 250
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 251
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 252
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 253
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 254
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 255
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 256
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 257
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 258
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 259
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 260
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 261
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 262
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 263
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 264
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 265
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 266
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 267
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 268
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 269
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 270
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 271
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 272
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 273
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 274
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 275
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 276
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 277
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 278
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 279
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 280
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 281
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 282
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 283
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 284
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 285
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 286
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 287
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 288
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 289
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 290
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 291
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 292
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 293
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 294
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 295
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 296
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 297
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 298
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 299
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 300
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 301
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 302
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 303
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 304
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 305
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 306
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 307
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 308
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 309
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 310
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 311
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 312
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 313
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 314
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 315
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 316
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 317
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 318
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 319
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 320
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 321
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 322
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 323
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 324
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 325
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 326
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 327
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 328
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 329
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 330
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 331
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 332
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 333
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 334
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 335
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 336
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 337
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 338
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 339
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 340
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 341
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 342
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 343
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 344
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 345
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 346
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 347
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 348
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 349
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 350
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 351
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 352
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 353
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 354
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 355
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 356
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 357
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 358
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 359
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 360
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 361
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 362
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 363
# ...
# Epoch: 380
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 381
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 382
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 383
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 384
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 385
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 386
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 387
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 388
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 389
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 390
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 391
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 392
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 393
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 394
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 395
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 396
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 397
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 398
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 399
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 400
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 401
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 402
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 403
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 404
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 405
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 406
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 407
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 408
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 409
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 410
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 411
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 412
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 413
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 414
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 415
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 416
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 417
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 418
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 419
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 420
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 421
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 422
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 423
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 424
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 425
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 426
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 427
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 428
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 429
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 430
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 431
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 432
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 433
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 434
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 435
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 436
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 437
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 438
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 439
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 440
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 441
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 442
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 443
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 444
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 445
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 446
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 447
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 448
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 449
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 450
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 451
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 452
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 453
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 454
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 455
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 456
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 457
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 458
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 459
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 460
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 461
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 462
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 463
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 464
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 465
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 466
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 467
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 468
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 469
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 470
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 471
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 472
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 473
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 474
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 475
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 476
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 477
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 478
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 479
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 480
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 481
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 482
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 483
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 484
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 485
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 486
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 487
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 488
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 489
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 490
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 491
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 492
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 493
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 494
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 495
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 496
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 497
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 498
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)
# Epoch: 499
# Train set: Average loss: 0.1590, Accuracy: 39847/40000 (100%)
# Test set: Average loss: 0.1590, Accuracy: 9961/10000 (100%)

# %%
# check weights after training
print("l1")
print(model.l1.weights.view(-1).cpu().detach().numpy()[0:4])
print(model.l1.centers.view(-1).cpu().detach().numpy()[0:4])
print(model.l1.sigs.view(-1).cpu().detach().numpy()[0:4])
# Out:
# l1
# [ 0.64928657 -0.6214736  -0.14267817 -0.60771143]
# [ 0.00258725 -0.00167843  0.00031047 -0.00245829]
# [5.3168154]

# %%
# l1
# [-3.7619257 -4.597318  -7.7643814 -7.976191 ]
# [-1. -1. -1. -1.]
# [100.]

# %%
# x, y = zip(*centers_per_update)
# plt.plot(x,y, marker='.', linestyle=' ')
# # plt.axis([-3,3, -3, 3])
# plt.grid()
# plt.show()

# plot dist to center
dists_per_update = [np.linalg.norm(data_centers-x) for x in centers_per_update]
plt.plot(dists_per_update, marker='.', linestyle=' ')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(sigmas_per_update, marker='.', linestyle=' ')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
