# %%
# comparison of how well a FGN model converted from a classic model performs

# note that to get the exact same results, a tanh(x) need to be added after each fgn layer.

# %%
from __future__ import print_function

# %%
import matplotlib as mpl
# set this 'backend' when using jupyter; do this before importing pyplot
mpl.use('nbagg')
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

import numpy as np

import sys
sys.path.append('/home/felix/Research/Adversarial Research/FGN---Research/')
import Finite_Gaussian_Network_lib as fgnl
import Finite_Gaussian_Network_lib.fgn_helper_lib as fgnh

# %%
# !gpustat
# Out:
# crescent  Wed Sep 18 16:33:58 2019
# [0] GeForce GTX 1080 | 71'C,  76 % |  6495 /  8119 MB | salami(2935M) felix(625M) salami(2923M)
# [1] GeForce GTX 1080 | 81'C,  88 % |  3417 /  8119 MB | felix(563M) denys(2281M) felix(561M)

# %%
# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
use_cuda = True
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")
print("Using device:", device)

# manualy set cuda device
torch.cuda.set_device(1)
# Out:
# CUDA Available:  True
# Using device: cuda

# %%
# # random seeds
# torch.manual_seed(999)
# np.random.seed(999)

# torch.backends.cudnn.deterministic = True
# torch.cuda.manual_seed_all(999)

# %%
# load MNIST data
batch_size = 32
(mnist_train_loader, mnist_val_loader, mnist_test_loader) = fgnh.mnist_dataloaders(batch_size)

# %%
### PART 1: Train classic feddforward model

# %%
# loss functions for the classic net
lmbda_l2 = (4.0*0.1/len(mnist_train_loader.dataset))
print(lmbda_l2)
      
classic_loss_func = fgnh.def_classical_cross_ent_loss(lmbda_l2)
# Out:
# 8e-06

# %%
# Initialize the classic network
hidden_l_nums = [32,32]
drop_p= 0.2

# %%
classic_model = fgnl.Feedforward_Classic_net(in_feats=28*28, out_feats=10, hidden_l_nums=hidden_l_nums, drop_p=drop_p).to(device)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-08ea96a5a860> in <module>()
# ----> 1 classic_model = fgnl.Feedforward_Classic_net(in_feats=28*28, out_feats=10, hidden_l_nums=hidden_l_nums, drop_p=drop_p).to(device)
#
# TypeError: __init__() takes at least 4 arguments (4 given)

# %%
classic_optimizer = optim.RMSprop(filter(lambda p: p.requires_grad, classic_model.parameters()),momentum=0.5)

# %%
# train the model
epochs = 5

# %%
classic_train_res = fgnh.train(classic_model, mnist_train_loader, 
                             classic_loss_func, classic_optimizer, epochs, save_hist=2, verbose=True, 
                             pred_func=fgnh.cross_ent_pred_accuracy, test_loader=mnist_test_loader)
# Out:
# Epoch 0 Train set - Average loss: 1.0559, Accuracy: 38805/60000 (65%)
# Test set - Average loss: 0.6186, Accuracy: 8141/10000 (81%)
# Epoch 1 Train set - Average loss: 0.4649, Accuracy: 52087/60000 (87%)
# Test set - Average loss: 0.4582, Accuracy: 8633/10000 (86%)
# Epoch 2 Train set - Average loss: 0.3788, Accuracy: 53593/60000 (89%)
# Test set - Average loss: 0.3759, Accuracy: 8943/10000 (89%)
# Epoch 3 Train set - Average loss: 0.3356, Accuracy: 54348/60000 (91%)
# Test set - Average loss: 0.3286, Accuracy: 9088/10000 (91%)
# Epoch 4 Train set - Average loss: 0.3136, Accuracy: 54644/60000 (91%)
# Test set - Average loss: 0.3601, Accuracy: 8993/10000 (90%)

# %%
### PART 2: Convert model to FGN

# %%
# step 1: Initialize the fgn network
print("hidden layers",hidden_l_nums)
print("drop_p=", drop_p)
fgn_model = fgnl.Feedforward_FGN_net(in_feats=28*28, out_feats=10, hidden_l_nums=hidden_l_nums, drop_p=drop_p).to(device)
# Out:
# hidden layers [16, 16, 16]
# drop_p= 0.0

# %%
# step 2: convert
fgnl.convert_classic_to_fgn(classic_model, fgn_model)

# %%
# test models
classic_test_res = fgnh.test(classic_model, mnist_train_loader, 
                             classic_loss_func, verbose=True, 
                             pred_func=fgnh.cross_ent_pred_accuracy)
# Out:
# Test set - Average loss: 0.3590, Accuracy: 53800/60000 (90%)

# %%
fgn_test_res = fgnh.test(fgn_model, mnist_train_loader, 
                             classic_loss_func, verbose=True, 
                             pred_func=fgnh.cross_ent_pred_accuracy)
# Out:
# Test set - Average loss: 89.2898, Accuracy: 5315/60000 (9%)

# %%
# unless tanh is added to the FGN model, this will not reproduce the results perfectly

# %%
# next idea: use grad descent to adjust sigmas and centers

# %%
for p in fgn_model.named_parameters():
    print(p)
# Out:
# ('hidden_layers.0.weights', Parameter containing:
# tensor([[ 0.0773,  0.0626,  0.0701,  ...,  0.0633,  0.0840,  0.1018],
#         [-0.2348, -0.2817, -0.2912,  ..., -0.2770, -0.2528, -0.2230],
#         [-0.0738, -0.0583, -0.0571,  ..., -0.0774, -0.0383, -0.0819],
#         ...,
#         [-0.0728, -0.0492, -0.1077,  ..., -0.0598, -0.0412, -0.0971],
#         [-0.0670, -0.0777, -0.0697,  ..., -0.0434, -0.0541, -0.0796],
#         [ 0.2034,  0.1624,  0.1747,  ...,  0.1764,  0.2032,  0.1492]],
#        device='cuda:1', requires_grad=True))
# ('hidden_layers.0.centers', Parameter containing:
# tensor([[6.4480e-05, 5.2232e-05, 5.8427e-05,  ..., 5.2752e-05, 7.0050e-05,
#          8.4870e-05],
#         [5.5173e-04, 6.6196e-04, 6.8414e-04,  ..., 6.5074e-04, 5.9408e-04,
#          5.2399e-04],
#         [6.1141e-05, 4.8304e-05, 4.7279e-05,  ..., 6.4111e-05, 3.1722e-05,
#          6.7803e-05],
#         ...,
#         [1.0075e-04, 6.8096e-05, 1.4914e-04,  ..., 8.2749e-05, 5.7008e-05,
#          1.3440e-04],
#         [7.7081e-05, 8.9371e-05, 8.0195e-05,  ..., 4.9927e-05, 6.2312e-05,
#          9.1655e-05],
#         [5.3607e-04, 4.2801e-04, 4.6039e-04,  ..., 4.6478e-04, 5.3549e-04,
#          3.9317e-04]], device='cuda:1', requires_grad=True))
# ('hidden_layers.0.sigmas', Parameter containing:
# tensor([1000., 1000., 1000., 1000., 1000., 1000., 1000., 1000., 1000., 1000.,
#         1000., 1000., 1000., 1000., 1000., 1000.], device='cuda:1',
#        requires_grad=True))
# ('hidden_layers.1.weight', Parameter containing:
# tensor([0.5461, 0.2787, 0.8551, 0.4433, 0.4587, 0.9304, 0.4843, 0.6815, 0.3271,
#         0.7216, 0.3985, 0.2263, 0.3146, 0.4722, 0.5051, 0.4558],
#        device='cuda:1', requires_grad=True))
# ('hidden_layers.1.bias', Parameter containing:
# tensor([-0.0195,  0.1099,  0.1216,  0.2010, -0.1876, -0.5971,  0.1232, -0.3136,
#          0.0790, -0.6046, -0.6489,  0.1046,  0.0911,  0.4514,  0.5135, -0.0195],
#        device='cuda:1', requires_grad=True))
# ('hidden_layers.2.weights', Parameter containing:
# tensor([[ 0.0030,  0.3471, -0.0392,  0.3559,  0.6592, -0.3087, -0.6341,  0.1097,
#           0.2131,  0.1390, -0.0251,  0.0020, -0.4075, -0.1392, -0.7187, -0.3047],
#         [ 0.1894, -0.7623, -0.5593, -0.3817, -0.5238, -0.3162, -0.5971, -0.4447,
#           0.2515, -0.4428, -0.7688,  0.2819, -0.2338,  0.0521,  0.1950,  0.3486],
#         [-0.0082,  0.6940,  0.4320,  0.1795, -0.0316, -0.3150,  0.1887, -0.6044,
#          -0.8380,  0.2513,  0.1950,  0.1088, -0.2240,  0.0046, -0.0196,  0.0499],
#         [-0.1064, -0.0251,  0.2174,  0.1120, -0.4289, -0.4154, -0.1661, -0.4776,
#           0.1740, -0.3921,  0.0388,  0.4883, -0.2630, -0.0033,  0.8901,  0.3616],
#         [-0.1762, -0.1690,  0.4403, -0.9393,  0.2215,  0.7751,  0.1389, -0.4576,
#          -0.2666, -0.2612,  0.4087, -0.4811,  0.1081,  0.3263, -0.1634, -1.0005],
#         [ 0.1666,  0.3492, -0.0793, -0.4046,  0.5500, -0.1836,  0.3149, -0.1896,
#           0.0635,  0.8339,  0.9337,  0.0205,  0.4265, -0.0110, -0.0626,  0.0451],
#         [ 0.1152, -0.0750, -0.2781,  0.1902, -0.1527, -0.3917, -0.5704,  0.0621,
#          -0.4328,  0.0068, -0.5962, -0.2222, -0.8090, -0.0366, -0.2076,  0.2771],
#         [-0.0926, -0.6364, -0.3131, -0.5305,  0.3103, -0.6094, -0.4226,  0.3013,
#           0.1941, -0.5030,  0.7777,  0.1816, -0.2753,  0.8608,  0.5326, -0.4497],
#         [ 0.7816,  0.0581, -0.0412,  0.3424, -0.4204, -0.3941,  0.1801,  0.4625,
#           0.1073,  0.0480, -0.0056,  0.0040,  0.2264, -0.1098, -0.0826, -0.7881],
#         [ 0.0696, -0.2520,  0.7634, -0.0453, -0.2909, -0.2228,  0.0227, -0.1386,
#          -0.0858, -0.1268, -0.8902,  0.2762,  0.0277, -0.5836, -0.1204,  0.3019],
#         [ 0.3354,  0.6086, -0.2977, -0.3898, -0.2851, -0.1720,  0.2240, -0.0613,
#          -0.0549,  0.3654, -0.7545,  0.0936, -0.0019,  0.4357,  0.0228,  0.4157],
#         [ 0.1874, -0.1034, -0.4023, -0.3746, -0.0309, -0.4439, -0.2360,  0.1807,
#          -0.3373,  0.3996, -0.3486,  0.0017,  0.1278, -0.9431, -0.6231,  0.3675],
#         [-0.0515,  0.8685, -0.3224, -0.5862,  0.2343, -0.1596,  0.0344, -0.6379,
#           8.7145e-03,  5.0619e-03,  1.4384e-04, -2.7455e-02, -7.4674e-03,
#           1.5780e-02,  1.1790e-02,  8.5790e-03,  3.3937e-05,  1.0116e-02,
#          -1.5222e-02],
#         [-3.2245e-02,  5.1427e-02,  1.4386e-02, -4.7233e-02, -3.6916e-02,
#           5.7816e-02,  4.4314e-02, -8.6892e-02,  5.4188e-02, -1.3156e-02,
#          -1.0517e-02,  3.1355e-02,  7.2103e-02, -2.2583e-01, -3.4004e-02,
#           4.9105e-02],
#         [-3.2889e-02,  2.9083e-02, -1.7492e-02,  6.4519e-02, -6.1964e-02,
#           6.0392e-02, -3.9588e-02, -7.5057e-02,  2.5588e-02, -1.2563e-02,
#           1.4284e-02, -1.8435e-02,  1.9768e-02, -1.8575e-01,  1.0287e-02,
#          -1.4736e-02],
#         [ 1.2463e-03, -8.0179e-03,  2.7581e-03, -2.6402e-03,  5.8704e-03,
#          -2.4425e-03, -1.0036e-03, -4.3409e-04,  5.3575e-03, -5.3293e-03,
#           5.8123e-03,  7.5069e-03,  6.9325e-04, -4.0725e-03, -4.8439e-03,
#          -1.6517e-04],
#         [-5.6430e-02,  1.3013e-01,  2.5432e-03,  1.7573e-01, -2.0957e-02,
#          -7.3093e-02,  1.9011e-01, -3.1279e-01, -1.4195e-01,  2.2908e-01,
#           1.5907e-01, -3.1616e-03, -7.5104e-02, -2.0437e-01,  3.8228e-01,
#           3.4491e-02]], device='cuda:1', requires_grad=True))
# ('hidden_layers.4.sigmas', Parameter containing:
# tensor([1000., 1000., 1000., 1000., 1000., 1000., 1000., 1000., 1000., 1000.,
#         1000., 1000., 1000., 1000., 1000., 1000.], device='cuda:1',
#        requires_grad=True))
# ('hidden_layers.5.weight', Parameter containing:
# tensor([ 1.1264,  1.0054,  1.3112,  1.4972,  0.9637, -0.6075, -0.7109,  1.1872,
#          1.3279,  0.8112,  0.6341,  0.8528,  0.6157,  1.1480,  0.9525,  1.4079],
#        device='cuda:1', requires_grad=True))
# ('hidden_layers.5.bias', Parameter containing:
# tensor([ 0.0097,  0.0599,  0.0647, -0.0465, -0.5779,  0.0313, -0.0133,  0.0633,
#          0.3601,  0.2056, -0.1492,  0.3106,  0.1569, -0.1848, -0.0016, -0.0127],
#        device='cuda:1', requires_grad=True))
# ('fl.weights', Parameter containing:
# tensor([[-0.2785, -0.4598, -0.7698,  0.7963,  0.5111, -0.1124, -0.8026, -0.5216,
#           0.0919, -0.5319,  0.4009,  0.6774, -0.5391,  0.6296,  0.2780, -0.3306],
#         [ 0.1848,  0.8854,  0.6800, -0.2904,  0.6100, -0.4613,  0.4274,  0.3396,
#          -0.0048,  0.7474,  0.1875, -0.2408, -0.9626,  0.1624, -0.0073,  0.9659],
#         [-0.5318, -0.8014,  0.4913, -0.2255, -0.7949,  0.0924, -0.0847, -0.1765,
#           0.4674, -0.3332,  0.8232, -0.1394,  0.2850, -0.0918,  0.3221,  0.5276],
#         [-0.5861,  0.6387, -0.3723, -0.1470, -0.3066, -0.0507,  0.1539, -0.4426,
#           0.3407,  0.7281, -0.4394, -0.0965,  0.0079, -0.4073, -0.2310, -0.5097],
#         [ 0.3868, -0.4314,  0.5360, -0.2727,  0.2883,  0.6905, -0.4084,  0.3469,
#          -0.7230, -0.4075, -0.3292, -0.7093,  0.3994,  0.5650,  0.4158, -0.4722],
#         [ 0.6756, -0.1218, -0.5635,  0.8527,  0.1748,  0.1711,  0.0412, -0.1430,
#           0.5059,  0.4688, -0.6034, -0.9531,  0.0773, -0.5755,  0.3870, -0.1625],
#         [ 0.6316, -0.2487,  0.3427,  0.9909,  0.4518, -1.0256, -0.6834, -0.5809,
#          -0.2225, -0.4607,  0.4880, -0.9697, -0.1311,  0.2054, -0.6818,  0.1168],
#         [ 0.0233, -0.1787, -0.1974, -0.5604, -0.0272,  0.1896, -1.0789,  0.1593,
#          -0.8640, -0.3122,  0.0449,  0.1669, -0.0715, -1.1484, -0.2104,  0.3383],
#         [ 0.0181, -0.2622, -0.1502,  0.1186,  0.3219,  0.0308,  0.5994,  0.2590,
#           0.5021,  0.5314, -0.3358,  0.6402,  0.6642,  0.5788, -1.0226,  0.2662],
#         [ 0.3327, -0.0482, -1.0248, -0.2331, -0.4897,  0.1749,  0.5503,  0.4216,
#          -1.0859, -0.2432, -0.3885,  0.4123,  0.4987,  0.1861,  0.3554, -0.5051]],
#        device='cuda:1', requires_grad=True))
# ('fl.centers', Parameter containing:
# tensor([[-0.0154, -0.0255, -0.0427,  0.0441,  0.0283, -0.0062, -0.0445, -0.0289,
#           0.0051, -0.0295,  0.0222,  0.0375, -0.0299,  0.0349,  0.0154, -0.0183],
#         [ 0.0148,  0.0708,  0.0544, -0.0232,  0.0488, -0.0369,  0.0342,  0.0271,
#          -0.0004,  0.0598,  0.0150, -0.0192, -0.0770,  0.0130, -0.0006,  0.0772],
#         [ 0.0278,  0.0419, -0.0257,  0.0118,  0.0416, -0.0048,  0.0044,  0.0092,
#          -0.0245,  0.0174, -0.0431,  0.0073, -0.0149,  0.0048, -0.0168, -0.0276],
#         [ 0.0612, -0.0667,  0.0389,  0.0153,  0.0320,  0.0053, -0.0161,  0.0462,
#          -0.0356, -0.0760,  0.0459,  0.0101, -0.0008,  0.0425,  0.0241,  0.0532],
#         [-0.0209,  0.0233, -0.0289,  0.0147, -0.0156, -0.0373,  0.0221, -0.0187,
#           0.0390,  0.0220,  0.0178,  0.0383, -0.0216, -0.0305, -0.0225,  0.0255],
#         [-0.0930,  0.0168,  0.0776, -0.1174, -0.0241, -0.0235, -0.0057,  0.0197,
#          -0.0696, -0.0645,  0.0831,  0.1312, -0.0106,  0.0792, -0.0533,  0.0224],
#         [ 0.0073, -0.0029,  0.0039,  0.0114,  0.0052, -0.0118, -0.0079, -0.0067,
#          -0.0026, -0.0053,  0.0056, -0.0112, -0.0015,  0.0024, -0.0078,  0.0013],
#         [-0.0013,  0.0100,  0.0110,  0.0312,  0.0015, -0.0106,  0.0601, -0.0089,
#           0.0481,  0.0174, -0.0025, -0.0093,  0.0040,  0.0640,  0.0117, -0.0188],
#         [-0.0009,  0.0133,  0.0076, -0.0060, -0.0163, -0.0016, -0.0304, -0.0131,
#          -0.0255, -0.0270,  0.0170, -0.0325, -0.0337, -0.0294,  0.0519, -0.0135],
#         [-0.0168,  0.0024,  0.0517,  0.0118,  0.0247, -0.0088, -0.0278, -0.0213,
#           0.0548,  0.0123,  0.0196, -0.0208, -0.0252, -0.0094, -0.0179,  0.0255]],
#        device='cuda:1', requires_grad=True))
# ('fl.sigmas', Parameter containing:
# tensor([1000., 1000., 1000., 1000., 1000., 1000., 1000., 1000., 1000., 1000.],
#        device='cuda:1', requires_grad=True))

# %%
fgn_sigmas_optimizer
# Out:
# RMSprop (
# Parameter Group 0
#     alpha: 0.99
#     centered: False
#     eps: 1e-08
#     lr: 0.01
#     momentum: 0.5
#     weight_decay: 0
# )

# %%
# loss functions for the fgn
lmbda_sigmas = 10.0*lmbda_l2
print(lmbda_sigmas)
      
fgn_loss_func = fgnl.def_fgn_cross_ent_loss(lmbda_l2, lmbda_sigmas)
# Out:
# 6.66666666667e-05

# %%
# train the converted model, but not the weights
epochs = 10
fgn_train_res = fgnh.train(fgn_model, mnist_train_loader, 
                             fgn_loss_func, fgn_sigmas_optimizer, epochs, save_hist=2, verbose=True, 
                             pred_func=fgnh.cross_ent_pred_accuracy, test_loader=mnist_test_loader)
# Out:
# Epoch 0 Train set - Average loss: 67.1128, Accuracy: 49121/60000 (82%)
# Test set - Average loss: 92.5522, Accuracy: 1009/10000 (10%)
# Epoch 1 Train set - Average loss: 66.9296, Accuracy: 49352/60000 (82%)
# Test set - Average loss: 84.8864, Accuracy: 1012/10000 (10%)
# Epoch 2 Train set - Average loss: 66.8038, Accuracy: 49463/60000 (82%)
# Test set - Average loss: 80.4849, Accuracy: 1045/10000 (10%)
# Epoch 3 Train set - Average loss: 66.6935, Accuracy: 49697/60000 (83%)
# Test set - Average loss: 77.8852, Accuracy: 1158/10000 (12%)
# Epoch 4 Train set - Average loss: 66.5930, Accuracy: 49799/60000 (83%)
# Test set - Average loss: 77.2787, Accuracy: 1113/10000 (11%)
# Epoch 5 Train set - Average loss: 66.4955, Accuracy: 49975/60000 (83%)
# Test set - Average loss: 75.8134, Accuracy: 1302/10000 (13%)
# Epoch 6 Train set - Average loss: 66.4025, Accuracy: 50185/60000 (84%)
# Test set - Average loss: 74.8636, Accuracy: 1353/10000 (14%)
# Epoch 7 Train set - Average loss: 66.3118, Accuracy: 50351/60000 (84%)
# Test set - Average loss: 74.1589, Accuracy: 1418/10000 (14%)
# Epoch 8 Train set - Average loss: 66.2216, Accuracy: 50518/60000 (84%)
# Test set - Average loss: 73.3401, Accuracy: 1653/10000 (17%)
# Epoch 9 Train set - Average loss: 66.1334, Accuracy: 50664/60000 (84%)
# Test set - Average loss: 73.0285, Accuracy: 1675/10000 (17%)

# %%
fgn_test_res = fgnh.test(fgn_model, mnist_train_loader, 
                             classic_loss_func, verbose=True, 
                             pred_func=fgnh.cross_ent_pred_accuracy)
# Out:
# Test set - Average loss: 7.5570, Accuracy: 9759/60000 (16%)
